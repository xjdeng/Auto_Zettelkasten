# %%
#see: https://stackoverflow.com/questions/64743583/which-10-words-has-the-highest-tf-idf-value-in-each-document-total
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from collections import defaultdict
import numpy as np
import re
import heapq
from sklearn.feature_extraction import text
import joblib

# %%
N = 3

# %%
def second_largest(arr):
    res = heapq.nlargest(2, arr)
    return res[1]

# %%
my_stop_words = text.ENGLISH_STOP_WORDS.union(["_","__","___"])

X,y = fetch_20newsgroups(return_X_y = True)
#X = X[0:1000]
tfidf = TfidfVectorizer(stop_words=my_stop_words)
X_tfidf = tfidf.fit_transform(X)#.toarray()
docs,words = X_tfidf.shape
doclookup = [[] for _ in range(docs)]
wordlookup = [[] for _ in range(words)]
#collookup = defaultdict(list)
row,col = X_tfidf.nonzero()
for r,c in zip(row,col):
    doclookup[r].append(c)
    wordlookup[c].append(r)
vocab = tfidf.vocabulary_
reverse_vocab = {v:k for k,v in vocab.items()}

feature_names = tfidf.get_feature_names()

best_tfidf = []

for i,doc in enumerate(doclookup):
    myset = set()
    myrow = list(X_tfidf[i,doclookup[i]].toarray()[0])
    reverse = {item:idx for item,idx in zip(myrow, doclookup[i])}
    descending = sorted(myrow, reverse=True)
    for item_idx in descending:
        if len(wordlookup[reverse[item_idx]]) > 1:
            myset.add(reverse_vocab[reverse[item_idx]])
            if len(myset) == N:
                break
    best_tfidf.append(myset)

# %%
"""
my_stop_words = text.ENGLISH_STOP_WORDS.union(["_","__","___"])

X,y = fetch_20newsgroups(return_X_y = True)
#X = X[0:1000]
tfidf = TfidfVectorizer(stop_words=my_stop_words)
X_tfidf = tfidf.fit_transform(X)#.toarray()
joblib.dump(X_tfidf, "sparse.pkl")
X_tfidf = X_tfidf.toarray()
#print([len(x) for x in X_tfidf.nonzero()])
vocab = tfidf.vocabulary_
reverse_vocab = {v:k for k,v in vocab.items()}

feature_names = tfidf.get_feature_names()

idx = X_tfidf.argsort(axis=1)

#tfidf_max10 = idx[:,-N:]

#best_tfidf = [set([reverse_vocab.get(item) for item in row]) for row in tfidf_max10 ]


best_tfidf = []
words = len(vocab)
reverse = idx[:,::-1]
for i,row in enumerate(reverse):
    myset = set()
    for j,item in enumerate(row):
        if second_largest(X_tfidf[:,item]) != 0:
            myset.add(reverse_vocab[item])
            if len(myset) == N:
                break
    best_tfidf.append(myset)
"""

# %%
best_tfidf
# Out:
# [{'car', 'lerxst', 'wam'},
#  {'clock', 'poll', 'si'},
#  {'180', 'powerbook', 'purdue'},
#  {'abraxis', 'harris', 'weitek'},
#  {'bugs', 'errors', 'warning'},
#  {'destruction', 'foxvog', 'weapons'},
#  {'bmdelane', 'treatment', 'uchicago'},
#  {'10mb', 'burst', 'scsi'},
#  {'icons', 'iscsvax', 'win'},
#  {'autodoubler', 'board', 'kerr'},
#  {'cmptrc', 'ducati', 'irwin'},
#  {'child', 'moral', 'parent'},
#  {'fc', 'fort', 'rod'},
#  {'flights', 'option', 'ssf'},
#  {'dryer', 'moving', 'purchased'},
#  {'mantis', 'mathew', 'trial'},
#  {'complexity', 'prestonm', 'tiff'},
#  {'car', 'insurance', 'year'},
#  {'amplifier', 'amplify', 'ritley'},
#  {'3b2', 'ncd', 'terminal'},
#  {'germany', 'keith', 'motto'},
#  {'captain', 'leafs', 'traded'},
#  {'catalog', 'rpwhite', 'scien'},
#  {'font', 'uafhp', 'window'},
#  {'loop', 'nodine', 'scsi'},
#  {'hinckley', 'onyx', 'virginia'},
#  {'nuclear', 'plants', 'water'},
#  {'arizona', 'biosci', 'joplin'},
#  {'god', 'intricate', 'wheaton'},
#  {'centerline', 'collisions', 'priorities'},
#  {'sony', 'stereo', 'theft'},
#  {'acne', 'actrix', 'teenage'},
#  {'exploding', 'ubc', 'unixg'},
#  {'arabs', 'askew', 'war'},
#  {'cipale', 'kaldis', 'rutgers'},
#  {'ists', 'mask', 'vanbiesbrouck'},
#  {'holonet', 'moa', 'static'},
#  {'amanda', 'clause', 'encryption'},
#  {'behanna', 'deductible', 'insurance'},
#  {'auto', 'revolver', 'semi'},
#  {'bonilla', 'krueger', 'schott'},
#  {'ncube', 'root', 'zod'},
#  {'digital', 'sam', 'western'},
#  {'bullpen', 'navarro', 'yesterday'},
#  {'batters', 'starters', 'viola'},
#  {'andrew', 'brunskill', 'cmu'},
#  {'emulator', 'iscs', 'wyse'},
#  {'csundh30', 'ers', 'movies'},
#  {'3v', '48v', 'toronto'},
#  {'18084tm', 'msu', 'space'},
#  {'failed', 'request', 'segment'},
#  {'ceremonial', 'gentile', 'sabbath'},
#  {'200', 'bj', 'canon'},
#  {'disease', 'km', 'mitchum'},
#  {'armenians', 'command', 'duke'},
#  {'crypto', 'stratus', 'sw'},
#  {'automatic', 'gear', 'throttle'},
#  {'cunyvm', 'plymouth', 'zazula'},
#  {'ini', 'updating', 'utility'},
#  {'cassini', 'probe', 'titan'},
#  {'blakey', 'dal', 'ug'},
#  {'msi', 'poitras', 'testing'},
#  {'cd', 'informix', 'toshiba'},
#  {'asuacad', 'cds', 'neville'},
#  {'atlanta', 'ford', 'phillips'},
#  {'infinite', 'infinity', 'tut'},
#  {'6889', 'tis', 'walker'},
#  {'atf', 'cs', 'lance'},
#  {'blask', 'religion', 'religious'},
#  {'dec', 'mattress', 'suresh'},
#  {'armenian', 'armenians', 'russian'},
#  {'callison', 'uokmax', 'uoknor'},
#  {'110vac', 'battery', 'jpl'},
#  {'aviad', 'oil', 'rdb1'},
#  {'arbor', 'bk', 'desonia'},
#  {'markz', 'ssc', 'zenier'},
#  {'key', 'phone', 'registered'},
#  {'acura', 'integra', 'miles'},
#  {'blind', 'bruno', 'windows'},
#  {'binah', 'brandeis', 'tsr'},
#  {'fatwa', 'islamic', 'rushdie'},
#  {'cameras', 'roby', 'watched'},
#  {'conference', 'csiro', 'dicta'},
#  {'0729', 'portal', 'walveranta'},
#  {'eliot', 'engine', 'mr2'},
#  {'cable', 'olson', 'scsi'},
#  {'bc', 'ctrltest', 'mfc'},
#  {'dresden', 'fonts', 'gif'},
#  {'acsu', 'buffalo', 'hammerl'},
#  {'assemblers', 'mcole', 'spock'},
#  {'2600', 'atari', 'pca103'},
#  {'aryan', 'collaboration', 'nazi'},
#  {'cis', 'gamma', 'rubin'},
#  {'gpf', 'oracle', 'simms'},
#  {'cray', 'latech', 'speedy'},
#  {'colorado', 'cua', 'dog'},
#  {'marine', 'naval', 'reserve'},
#  {'billh', 'cwi', 'greed'},
#  {'adam', 'begat', 'daughters'},
#  {'haston', 'hijaak', 'tmc'},
#  {'code', 'toolkit', 'windows'},
#  {'ericsson', 'neoucom', 'uhura'},
#  {'harleys', 'hpcc01', 'stafford'},
#  {'cbs', 'horton', 'molbio'},
#  {'anas', 'liar', 'omran'},
#  {'mhz', 'scope', 'scopes'},
#  {'decoupling', 'govindan', 'ravin'},
#  {'balanced', 'hops', 'nasa'},
#  {'ati', 'genoa', 'pallis'},
#  {'lorne', 'sun', 'tickets'},
#  {'cramer', 'optilink', 'relationships'},
#  {'cuny', 'data', 'serial'},
#  {'controller', 'keegan', 'yale'},
#  {'breaker', 'laurentian', 'maynard'},
#  {'dan', 'holiday', 'uiuc'},
#  {'issued', 'jaeger', 'khomeini'},
#  {'dyer', 'hismanal', 'spdcc'},
#  {'amanda', 'intercon', 'nren'},
#  {'ethan', 'manager', 'window'},
#  {'doink', 'jbreed', 'pluto'},
#  {'christianity', 'god', 'sherlette'},
#  {'karr', 'mjs', 'turn'},
#  {'hades', 'pin', 'simms'},
#  {'forensic', 'listserv', 'substitution'},
#  {'hulman', 'rose', 'whitsebd'},
#  {'42', '_______________________________', 'joachim'},
#  {'ibm', 'n4hy', 'strom'},
#  {'guns', 'holster', 'threat'},
#  {'bradley', 'camelot', 'melido'},
#  {'hydro', 'jody', 'levine'},
#  {'amoco', 'trc', 'zmed16'},
#  {'carson', 'washington', 'weather'},
#  {'bach', 'dbase', 'iv'},
#  {'agdam', 'armenian', 'turkish'},
#  {'development', 'hlvs', 'launcher'},
#  {'crchh410', 'god', 'satan'},
#  {'jmann', 'pubs', 'stratus'},
#  {'acpub', 'north1', 'seth'},
#  {'2a42dubinski', 'csd', 'mu'},
#  {'condem', 'homosexuality', 'verses'},
#  {'anello', 'foods', 'supplements'},
#  {'182', '333', 'snf'},
#  {'24x', 'cdc', 'slc'},
#  {'encore', 'ericm', 'microunity'},
#  {'a86', 'ax', 'max'},
#  {'noring', 'quack', 'quacks'},
#  {'30am', '4679', 'video'},
#  {'invaded', 'nik', 'peace'},
#  {'apostle', 'apostles', 'fisher'},
#  {'eng', 'sysmgr', 'umd'},
#  {'sdsu', 'ucssun1', 'weston'},
#  {'brasil', 'da', 'object'},
#  {'amir', 'jews', 'land'},
#  {'maneuver', 'roll', 'shuttle'},
#  {'cpu', 'duo', 'indiana'},
#  {'brandeis', 'new', 'pip'},
#  {'car', 'insurance', 'youngblood'},
#  {'comes', 'god', 'king'},
#  {'cview', 'god', 'moscom'},
#  {'morgan', 'socs', 'technology'},
#  {'hasan', 'israel', 'water'},
#  {'57x', 'death', 'deaths'},
#  {'cindy', 'ics', 'tittle'},
#  {'noye', 'satan', 'vera'},
#  {'cubs', 'harkey', 'symantec'},
#  {'bobc', 'boeing', 'brochures'},
#  {'blazers', 'oakleys', 'purdue'},
#  {'mcdowell', 'ranger', 'ticket'},
#  {'hiram', 'package', 'refund'},
#  {'cmich', 'cmuvm', 'radio'},
#  {'cramer', 'men', 'optilink'},
#  {'linux', 'whiting', 'windows'},
#  {'cellar', 'colons', 'darling'},
#  {'kimd', 'projector', 'rpi'},
#  {'cmu', 'ofnmao_00iv1a6kyd2', 'todd'},
#  {'font', 'ti', 'xterm'},
#  {'borland', 'iastate', 'richard'},
#  {'geb', 'legal', 'tuberculosis'},
#  {'desonia', 'ibm', 'tripling'},
#  {'avery', 'blauser', 'braves'},
#  {'dubin', 'ringing', 'tinnitus'},
#  {'mprgate', 'patterson', 'rfi'},
#  {'dyer', 'paulson', 'spdcc'},
#  {'braking', 'technique', 'traction'},
#  {'assembly', 'plastic', 'tower'},
#  {'hd', 'ram', 'unimi'},
#  {'advtech', 'novak', 'uswest'},
#  {'movie', 'quicktime', 'rpi'},
#  {'garyg', 'mentorg', 'warren'},
#  {'indiana', 'kssimon', 'modem'},
#  {'ebosco', 'oracle', 'sean'},
#  {'kevin', 'mail', 'qwk'},
#  {'128', 'bits', 'keys'},
#  {'berkeley', 'industries', 'scientific'},
#  {'lowell', 'lreiter', 'tufts'},
#  {'eicn', 'perret', 'xv'},
#  {'audio', 'circuit', 'relays'},
#  {'depression', 'promiscuity', 'sex'},
#  {'destruction', 'stratus', 'weapons'},
#  {'hughes', 'ral', 'rpi'},
#  {'firearm', 'hays', 'purchased'},
#  {'10w40', '20w50', 'drives'},
#  {'clamen', 'cmu', 'cs'},
#  {'illusion', 'objectively', 'reality'},
#  {'alice', 'k_p', 'key'},
#  {'baalke', 'funding', 'kelvin'},
#  {'disk', 'sdrc', 'uart'},
#  {'abbott', 'trunk', 'water'},
#  {'flyers', 'gaa', 'roussel'},
#  {'energy', 'mccall', 'perpetual'},
#  {'belief', 'beliefs', 'believe'},
#  {'annotation', 'cerna', 'ntep'},
#  {'gun', 'manes', 'rates'},
#  {'csir', 'dsp', 'za'},
#  {'accelerated', 'howtek', 'rick'},
#  {'annick', 'msg', 'sdf'},
#  {'finnegan', 'navo', 'navy'},
#  {'acme', 'apple', 'released'},
#  {'amino', 'essential', 'glutamate'},
#  {'federal', 'land', 'tax'},
#  {'arff', 'ch', 'nerone'},
#  {'blind', 'faith', 'god'},
#  {'fourd', 'francesca_m', 'wimp'},
#  {'0565', 'bill_paxton', 'fourd'},
#  {'fan', 'io21087', 'maine'},
#  {'concealed', 'il', 'syck5280'},
#  {'costly', 'dg', 'memorial'},
#  {'bnr', 'dgraham', 'semitism'},
#  {'defence', 'homicides', 'self'},
#  {'bhp', 'limit', 'vetoed'},
#  {'claussen', 'group', 'psychoactives'},
#  {'font', 'ncsu', 'window'},
#  {'alaska', 'aurora', 'henry'},
#  {'dmoney', 'stamber', 'tickets'},
#  {'backup', 'defrag', 'norton'},
#  {'file', 'redirect', 'servis'},
#  {'nd', 'sam', 'vma'},
#  {'centaur', 'combo', 'jgreen'},
#  {'piano', 'shapiro', 'yale'},
#  {'bryan', 'printer', 'utah'},
#  {'deon', 'scripture', 'strydom'},
#  {'church', 'lmh', 'poland'},
#  {'140', 'aris', 'pss'},
#  {'cheng', 'd2cheng', 'dominic'},
#  {'assuring', 'escrow', 'sector'},
#  {'cheap', 'gtoal', 'phone'},
#  {'bontchev', 'hamburg', 'informatik'},
#  {'placebo', 'subjects', 'test'},
#  {'john', 'luke', 'mark'},
#  {'ftcollinsco', 'lewczyk', 'ncr'},
#  {'andover', 'mail', 'merrimack'},
#  {'arm', 'squats', 'sudden'},
#  {'engin', 'ingles', 'tortured'},
#  {'graders', 'lsd', 'marijuana'},
#  {'dct', 'greig', 'mcs'},
#  {'ini', 'notepad', 'sysedit'},
#  {'brewer', 'fanning', 'lib'},
#  {'access', 's1', 's2'},
#  {'better', 'rookie', 'year'},
#  {'esdi', 'ide', 'ivan'},
#  {'aids', 'lenient', 'sex'},
#  {'bases', 'clinton', 'seawolf'},
#  {'keys', 'pockets', 'women'},
#  {'agreement', 'pirates', 'simmons'},
#  {'alaska', 'prize', 'small'},
#  {'k_mullin', 'oz', 'plymouth'},
#  {'oilers', 'podein', 'rangers'},
#  {'000', 'israel', 'killed'},
#  {'ncr', 'orwig', 'shaft'},
#  {'dia', 'nemo', 'upm'},
#  {'card', 'glenn', 'rmit'},
#  {'cwru', 'po', 'quattro'},
#  {'aura', 'neurologic', 'zisfein'},
#  {'101', 'berger', 'brandeis'},
#  {'centerline', 'cup', 'jimf'},
#  {'es', 'imp', 'sim'},
#  {'bits', 'key', 'silverton'},
#  {'gcohen', 'ncube', 'scanner'},
#  {'cmwolf', 'electronics', 'willisw'},
#  {'approved', 'gtoal', 'modems'},
#  {'berkeley', 'mpc', 'rom'},
#  {'kuleuven', 'leuven', 'wimvh'},
#  {'dseg', 'pyron', 'ti'},
#  {'box', 'jay', 'skidmore'},
#  {'rayshade', 'rle', 'washington'},
#  {'batteries', 'freenet', 'michel'},
#  {'eff', 'heh', 'rita'},
#  {'assumption', 'jung', 'mary'},
#  {'aquinas', 'kuhub', 'miner'},
#  {'desc', 'laptop', 'toshiba'},
#  {'colormap', 'cursor', 'dialogshell'},
#  {'george', 'gp2011', 'matt'},
#  {'discovery', 'sun', 'uk'},
#  {'950', 'case', 'quadra'},
#  {'aluminum', 'ammunition', 'mtu'},
#  {'israeli', 'questions', 'true'},
#  {'dodgers', 'ingres', 'la'},
#  {'pb2esac', 'rider', 'tank'},
#  {'ice', 'octopus', 'symbolism'},
#  {'jews', 'land', 'zbib'},
#  {'giveaways', 'night', 'sponser'},
#  {'arms', 'bear', 'holland'},
#  {'cornell', 'shaft', 'virago'},
#  {'church', 'coptic', 'monophysitism'},
#  {'magnus', 'scalpers', 'tickets'},
#  {'040', 'ameres', 'powerpc'},
#  {'compilers', 'csir', 'za'},
#  {'click', 'whirr', 'whirrr'},
#  {'gc', 'gxxor', 'mydisplay'},
#  {'grayscale', 'mac', 'wyvern'},
#  {'judge', 'kmr4', 'tammy'},
#  {'cutter', 'gloster', 'nc'},
#  {'birthday', 'happy', 'israel'},
#  {'jhuapl', 'ncmoore2', 'tapes'},
#  {'parts', 'robie', 'umbc'},
#  {'keith', 'motto', 'religion'},
#  {'creation', 'susan', 'uchicago'},
#  {'ch981', 'cleveland', 'tony'},
#  {'bb', 'ddd', 'sscl'},
#  {'iastate', 'kv07', 'warren'},
#  {'hopper', 'r5', 'sony'},
#  {'concert', 'courter', 'naomi'},
#  {'henry', 'hst', 'reboost'},
#  {'nhl', 'pick', 'viktor'},
#  {'lemons', 'x11r6', 'xremote'},
#  {'archiving', 'concert', 'warrant'},
#  {'hare', 'tripp', 'tuscon'},
#  {'bedroom', 'condo', 'room'},
#  {'_______________________________', 'french', 'joachim'},
#  {'bone', 'sacrum', 'vertebrae'},
#  {'chen', 'col', 'msg'},
#  {'optilink', 'parade', 'walsh'},
#  {'columbia', 'cunixa', 'marc'},
#  {'feldman', 'hfeldman', 'howard'},
#  {'002251w', 'abbot', 'jason'},
#  {'brunel', 'cs89mcd', 'uk'},
#  {'bmp', 'gif', 'scott'},
#  {'cactus', 'joe', 'rider'},
#  {'aardvark', 'chihuahua', 'uoknor'},
#  {'charles', 'emmons', 'trintex'},
#  {'brown', 'leo', 'unm'},
#  {'breathing', 'chest', 'liquid'},
#  {'analog', 'willie', 'wilson'},
#  {'cost', 'henry', 'launch'},
#  {'rochester', 'times_', 'wycliffe'},
#  {'clubs', 'waivers', 'year'},
#  {'com1', 'howtek', 'phil'},
#  {'aid', 'conservatives', 'julie'},
#  {'flipping', 'massey', 'vga'},
#  {'berkeley', 'methodologically', 'mow'},
#  {'espn', 'florida', 'playoffs'},
#  {'electric', 'fields', 'unocal'},
#  {'bskendig', 'creation', 'kendig'},
#  {'jmc', 'mccarthy', 'stanford'},
#  {'christianity', 'especially', 'mwhaefne'},
#  {'c5r7tv', 'kubey', 'sgi'},
#  {'colostate', 'level', 'wallacen'},
#  {'austin', 'ibm', 'leapman'},
#  {'mac', 'meg', 'motorola'},
#  {'lucifer', 'satan', 'theology'},
#  {'neale', 'pioneer', 'rochester'},
#  {'tax', 'vat', 'veal'},
#  {'cook', 'layne', 'mdc'},
#  {'hubble', 'observations', 'uranus'},
#  {'bony', 'bony1', 'jake'},
#  {'acne', 'clearasil', 'teenage'},
#  {'father', 'son', 'spirit'},
#  {'intel', 'motif', 'x11r5'},
#  {'aero', 'aerospace', 'lau'},
#  {'descartes', 'etl', 'riggs'},
#  {'cri', 'grace', 'nz'},
#  {'cartlidge', 'cs1442aq', 'weeks'},
#  {'00', '15', 'magazine'},
#  {'abc', 'plane', 'sphere'},
#  {'80ns', 'rvenkate', 'simms'},
#  {'card', 'ega', 'maine'},
#  {'adobe', 'cjackson', 'db'},
#  {'occam', 'okcforum', 'razor'},
#  {'kurds', 'soviet', 'turks'},
#  {'acb', 'berlin', 'stefan'},
#  {'serc', 'shadow', 'uk'},
#  {'cramer', 'fetishes', 'immoral'},
#  {'bears', 'national', 'psychos'},
#  {'dak988s', 'president', 'smsu'},
#  {'davide', 'qmw', 'rr'},
#  {'corn', 'paulson', 'uga'},
#  {'betts', 'displays', 'lcd'},
#  {'atheists', 'death', 'hell'},
#  {'asphaug', 'erik', 'zephyr'},
#  {'mark', 'ocs', 'ocsmd'},
#  {'mathew', 'morality', 'objective'},
#  {'kuiper', 'nicoll', 'smiley'},
#  {'mac', 'sdchemw2', 'stereo'},
#  {'behr', 'cable', 'ilstu'},
#  {'columbia', 'cunixb', 'freeman'},
#  {'color', 'default', 'xterm'},
#  {'deal', 'hes', 'return'},
#  {'grape', 'nswses', 'subscribe'},
#  {'cilia', 'pediatrician', 'syndrome'},
#  {'hsieh', 'julia', 'micron'},
#  {'andy', 'clipper', 'hooper'},
#  {'ferguson', 'george', 'rochester'},
#  {'josephson', 'microphone', 'nyu'},
#  {'mulvey', 'oswego', 'wpi'},
#  {'france', 'nuclear', 'towers'},
#  {'antonio', 'balsamo', 'stargl'},
#  {'detroit', 'mtroyal', 'riel'},
#  {'durham', 'ellis', 'uk'},
#  {'cobb', 'kevin', 'morality'},
#  {'pov', 'tamsun', 'tga'},
#  {'ibm', 'lethal', 'mjp'},
#  {'bytes', 'filemanager', 'select'},
#  {'administration', 'geoff', 'kuenning'},
#  {'markz', 'musone', 'ssc'},
#  {'manu', 'oas', 'olivetti'},
#  {'_____', 'bombed', 'centerline'},
#  {'fish', 'tvtwm', 'vanderpool'},
#  {'karen', 'westford', 'xtici'},
#  {'harmon', 'harmons', 'sommer'},
#  {'selections', 'wolfram', 'wri'},
#  {'davpa', 'ida', 'partain'},
#  {'abstinence', 'education', 'pregnancy'},
#  {'marriage', 'priest', 'required'},
#  {'17', 'msstate', 'pork'},
#  {'caltech', 'chimps', 'keith'},
#  {'_____',
#   '__________________________________________________________________________',
#   'characterization'},
#  {'abcd', 'akerman', 'doug'},
#  {'circuit', 'screen', 'verity'},
#  {'aftersleep', 'xie', 'zxxst'},
#  {'alec', 'alee', 'font'},
#  {'720', 'hpwala', 'limagen'},
#  {'battery', 'draining', 'recharge'},
#  {'aide', 'hit', 'space'},
#  {'bontchev', 'hamburg', 'informatik'},
#  {'greg', 'ratings', 'webo'},
#  {'albany', 'ls8139', 'silverberg'},
#  {'apostasy', 'khomeini', 'rushdie'},
#  {'logo', 'mask', 'pens'},
#  {'graphite', 'metrics', 'tomh'},
#  {'andrea', 'sni', 'sto'},
#  {'ingr', 'rebuilding', 'tcsteven'},
#  {'buffalo', 'captain', 'traded'},
#  {'african', 'jesus', 'semitic'},
#  {'indyvax', 'libya', 'stop'},
#  {'bourke', 'christi', 'liturgy'},
#  {'manta', 'opel', 'uiuc'},
#  {'cable', 'lock', 'steel'},
#  {'database', 'escrow', 'exabyte'},
#  {'_true', 'fisher', 'indiana'},
#  {'3r6', 'onions', 'std'},
#  {'408', '448', 'clock'},
#  {'klinger', 'umanitoba', 'wave'},
#  {'funding', 'henry', 'spacecraft'},
#  {'hasan', 'israel', 'water'},
#  {'caronni', 'germano', 'key'},
#  {'hahn', 'spot', 'uwm'},
#  {'csl', 'nra', 'strait'},
#  {'iastate', 'justin', 'party'},
#  {'destruction', 'eternal', 'hell'},
#  {'deltabox', 'frame', 'klinger'},
#  {'jayne', 'kulikauskas', 'patiently'},
#  {'carb', 'convex', 'screws'},
#  {'marshatt', 'purdue', 'zauberer'},
#  {'csd4', 'qazi', 'uwm'},
#  {'equinox', 'hats', 'vinyl'},
#  {'bezier', 'detecting', 'oeinck'},
#  {'button', 'horn', 'throttle'},
#  {'challenger', 'software', 'wingert'},
#  {'contrary', 'evidence', 'virgilio'},
#  {'andi', 'hamaza', 'jake'},
#  {'jorge', 'sun', 'typewriter'},
#  {'kings', 'melrose', 'stauber'},
#  {'behunin', 'games', 'mdt'},
#  {'biggest', 'player', 'savard'},
#  {'deluca', 'gatech', 'matthew'},
#  {'adam', 'rivers', 'sea'},
#  {'blessed', 'forgiven', 'sins'},
#  {'hindered', 'jayne', 'prayer'},
#  {'hanlan', 'keithh', 'motorcycling'},
#  {'0114', 'demers', 'ucsd'},
#  {'behaviour', 'morality', 'natural'},
#  {'amitriptyline', 'banks', 'geb'},
#  {'gm', 'murray', 'uvic'},
#  {'386sx', 'controller', 'settings'},
#  {'house', 'lords', 'senate'},
#  {'memory', 'tamu', 'upper'},
#  {'harley', 'request', 'thinkage'},
#  {'lm', 'margoli', 'violation'},
#  {'fenway', 'rpi', 'umassd'},
#  {'duo', 'fung', 'ram'},
#  {'hays', 'raid', 'sheriff'},
#  {'argument', 'argumentum', 'fallacy'},
#  {'gm', 'gmr', 'toyota'},
#  {'hite', 'shite', 'unf'},
#  {'hockey', 'maynard', 'playoff'},
#  {'okcforum', 'omnipotence', 'rules'},
#  {'a137490', 'eros', 'tut'},
#  {'erika', 'grow', 'lingers'},
#  {'m0', 'm9', 'mv'},
#  {'lawn', 'mower', 'riding'},
#  {'kaist', 'kr', 'rtf'},
#  {'computer', 'gets', 'locked'},
#  {'det', 'leads', 'shots'},
#  {'greece', 'greek', 'turkish'},
#  {'acid', 'amino', 'glutamate'},
#  {'batf', 'cdt', 'stratus'},
#  {'127', 'byte', 'rgb'},
#  {'andi', 'palestinians', 'suffered'},
#  {'ad', 'dan', 'portal'},
#  {'force', 'islam', 'islamic'},
#  {'cook', 'enzo', 'sky'},
#  {'drive', 'jester', 'michael'},
#  {'apple', 'hades', 'simms'},
#  {'_________', 'exe', 'goudswaard'},
#  {'caron', 'gun', 'restraining'},
#  {'actix', 'eecg', 'wongda'},
#  {'144', '28', 'mvp'},
#  {'3d', 'msstate', 'trb3'},
#  {'rcs8', 'sprecher', 'syquest'},
#  {'altitude', 'cities', 'mdavcr'},
#  {'amoco', 'johnh', 'simms'},
#  {'3fgx', 'nec', 'umass'},
#  {'beam', 'col', 'crow'},
#  {'absolute', 'absolutes', 'mistakes'},
#  {'constantinople', 'empire', 'sack'},
#  {'game', 'games', 'snes'},
#  {'odometer', 'pulses', 'scn'},
#  {'diamond', 'hartmann', 'lance'},
#  {'exhaust', 'intake', 'pressure'},
#  {'mankind', 'moral', 'morality'},
#  {'borland', 'libraries', 's3'},
#  {'debugger', 'turbo', 'video'},
#  {'dlo', 'hunting', 'ifas'},
#  {'canon', 'enzo', 'nasa'},
#  {'ncr', 'options', 'sandiego'},
#  {'tektronix', 'tv', 'tvi'},
#  {'anas', 'liar', 'omran'},
#  {'knots', 'ri', 'vi'},
#  {'jed', 'pollux', 'usc'},
#  {'herzog', 'sparcclassic', 'sunsoft'},
#  {'clemens', 'meaddata', 'sox'},
#  {'css', 'itd', 'sweda'},
#  {'heath', 'uga', 'unbalanced'},
#  {'khettry', 'testing', 'utk'},
#  {'2600', 'mycal', 'netacsys'},
#  {'astronaut', 'nasa', 'pilot'},
#  {'cin', 'davis', 'lynch'},
#  {'engine', 'mr2', 'noisy'},
#  {'440mhz', 'anomaly', 'der'},
#  {'dub', 'sunday', 'willing'},
#  {'ohio', 'simms', 'ytwu'},
#  {'importance', 'meaning', 'mussack'},
#  {'mcluhan', 'siggraph', 'toronto'},
#  {'ford', 'slee01', 'srl'},
#  {'adjective', 'king', 'kyle'},
#  {'bla', 'null', 'widget'},
#  {'israel', 'naftaly', 'nstramer'},
#  {'produced', 'property', 'savages'},
#  {'abyss', 'breathing', 'liquid'},
#  {'lmsc', 'lockheed', 'slagle'},
#  {'factoring', 'kl', 'neuhaus'},
#  {'earle', 'isolar', 'twm'},
#  {'eisa', 'korenek', 'motherboard'},
#  {'alaa', 'naftaly', 'zeineldine'},
#  {'csd4', 'qazi', 'uwm'},
#  {'den', 'p2', 'p3'},
#  {'aids', 'sin', 'ttt'},
#  {'1x', 'ae', 'ep'},
#  {'heriot', 'printer', 'stuart'},
#  {'images', 'ruu', 'unocal'},
#  {'ide', 'kepler', 'unh'},
#  {'armenian', 'armenians', 'sumgait'},
#  {'catholic', 'church', 'liturgy'},
#  {'hydro', 'jody', 'levine'},
#  {'kaldis', 'rolla', 'umr'},
#  {'cfaehl', 'itc', 'kraken'},
#  {'desktop', 'holding', 'rebuild'},
#  {'agr00', 'amdahl', 'sandvik'},
#  {'bios', 'motherboard', 'ncd'},
#  {'18084tm', 'billion', 'space'},
#  {'keith', 'lions', 'moral'},
#  {'400', 'bgardner', 'twin'},
#  {'3352', 'bnr', 'uk'},
#  {'period', 'pp', 'scorer'},
#  {'imag', 'linux', 'schaefer'},
#  {'elin', 'rainer', 'server'},
#  {'mattingly', 'skeptical', 'snow'},
#  {'asked', 'chloupek', 'ohio'},
#  {'eds', 'jan', 'vandenbrande'},
#  {'change', 'keele', 'licensed'},
#  {'hudson', 'immoral', 'pain'},
#  {'concealed', 'law', 'officials'},
#  {'bgu', 'vent', 'windows'},
#  {'cryptography', 'harvard', 'kubo'},
#  {'dortmund', 'phonetic', 'weidlich'},
#  {'click', 'whirr', 'whirrr'},
#  {'chad', 'lehigh', 'ungo'},
#  {'beckman', 'pkp', 'rsa'},
#  {'60', 'loral', 'mile'},
#  {'doug', 'drivers', 'stealth'},
#  {'barbara', 'gifford', 'paradox'},
#  {'ncr', 'thompson', 'tvi'},
#  {'geo', 'neo', 'tomcat'},
#  {'ohio', 'oil', 'ubc'},
#  {'bob', 'subliminal', 'tv'},
#  {'72', 'aust', 'townsville'},
#  {'liverpool', 'spss', 'wooff'},
#  {'452', 'comp', 'russ'},
#  {'arena', 'mall', 'neoucom'},
#  {'acceleration', 'accelerations', 'amruth'},
#  {'amit', 'open', 'yali'},
#  {'harding', 'nunnally', 'sandvik'},
#  {'food', 'lundby', 'msg'},
#  {'arndt', 'comic', 'gac'},
#  {'absolute', 'absolutes', 'truth'},
#  {'bullet', 'halat', 'mathew'},
#  {'chris', 'memphis', 'virginia'},
#  {'550', 'elef', 'smarmy'},
#  {'shaft', 'stafford', 'wheelies'},
#  {'aedc', 'csiro', 'gooch'},
#  {'howard', 'moy', 'near'},
#  {'cybernet', 'rocks', 'vlasis'},
#  {'kevin', 'purdue', 'stamber'},
#  {'gxxor', 'rectangle', 'rectangles'},
#  {'lee', 'sv', 'tosspot'},
#  {'indiana', 'nate', 'psych'},
#  {'centrifuge', 'lzsc', 'rjf'},
#  {'gl', 'pyeatt', 'texaco'},
#  {'com', 'dec', 'portal'},
#  {'brian', 'ceccarelli', 'lpl'},
#  {'apple', 'meg', 'simms'},
#  {'differential', 'lane', 'startled'},
#  {'parc', 'sale', 'xerox'},
#  {'ching', 'fledgling', 'wpi'},
#  {'karma', 'lives', 'reincarnation'},
#  {'milligan', 'nancy', 'rude'},
#  {'cylinder', 'joni', 'master'},
#  {'art', 'cbnewsh', 'martial'},
#  {'dsc', 'gemini', 'gsfc'},
#  {'curves', 'detecting', 'oeinck'},
#  {'cardhu', 'dominik', 'dundee'},
#  {'dak988s', 'smsu', 'vma'},
#  {'gay', 'homosexual', 'men'},
#  {'brian', 'jesus', 'john'},
#  {'attacks', 'civilians', 'israel'},
#  {'68040', 'lazer', 'wpi'},
#  {'chevron', 'nosebleeds', 'zalan'},
#  {'floggings', 'orient', 'sex'},
#  {'ico', 'okcforum', 'osrhe'},
#  {'fbi', 'gas', 'koresh'},
#  {'ata', 'hfsi', 'jesus'},
#  {'manu', 'siblings', 'ws_thickframe'},
#  {'rand', 'tubes', 'uv'},
#  {'dolven', 'doug', 'montana'},
#  {'ecst', 'library', 'resource'},
#  {'jt', 'magnus', 'ohio'},
#  {'innocent', 'murder', 'objective'},
#  {'bear', 'noaa', 'search'},
#  {'armenia', 'soviet', 'turkish'},
#  {'car', 'km', 'maxima'},
#  {'brocku', 'spartan', 'tmc'},
#  {'grant', 'totten', 'trentu'},
#  {'bus', 'ide', 'sec'},
#  {'geb', 'rebound', 'weight'},
#  {'fielding', 'robinson', 'santo'},
#  {'584', '611', '616'},
#  {'colorado', 'davewood', 'rockies'},
#  {'logname', 'mccoy', 'xterm'},
#  {'atlantaga', 'ncr', 'unpatriotic'},
#  {'cubs', 'era', 'guzman'},
#  {'br', 'isc', 'libertarians'},
#  {'alomar', 'baerga', 'eskimo'},
#  {'belvedere', 'gatech', 'prism'},
#  {'kkk', 'passe', 'rkba'},
#  {'assistance', 'economic', 'palestinian'},
#  {'ini', 'svein', 'updating'},
#  {'integra', 'ls', 'peng'},
#  {'duke', 'ipx', 'ndd'},
#  {'256', 'hardy', 'washington'},
#  {'cbnewsl', 'islanders', 'mcgill'},
#  {'1d7', 'mike', 'umn'},
#  {'claremont', 'gospel', 'origins_'},
#  {'89', 'trunk', 'water'},
#  {'greg', 'grogers', 'slac'},
#  {'blah', 'halat', 'islam'},
#  {'bios', 'date', 'wrap'},
#  {'csx', 'grissom', 'ulowell'},
#  {'government', 'turkish', 'usenet'},
#  {'dishonest', 'ncr', 'wilson'},
#  {'anger', 'angry', 'emotions'},
#  {'caltech', 'ico', 'keith'},
#  {'israel', 'israeli', 'nazis'},
#  {'devil', 'jah', 'man'},
#  {'6mb', 'file', 'w4w'},
#  {'clipper', 'fairchild', 'intergraph'},
#  {'rogers', 'tesla', 'underwater'},
#  {'grahm', 'increases', 'technet'},
#  {'extant', 'slac', 'stanford'},
#  {'brocku', 'spartan', 'tmc'},
#  {'dunn', 'phones', 'roofs'},
#  {'files', 'jpg', 'otis'},
#  {'250', 'henson', 'ninja'},
#  {'bits', 'block', 'wiretap'},
#  {'kidney', 'stones', 'wvnvms'},
#  {'isc', 'rit', 'ritvax'},
#  {'cramer', 'fogarty', 'professors'},
#  {'drawindex', 'mydisplay', 'palette_colors'},
#  {'human', 'jesus', 'nestorius'},
#  {'existance', 'mwm', 'stefan'},
#  {'images', 'pixel', 'weber'},
#  {'grissom', 'number', 'operator'},
#  {'hdf', 'markus', 'octavia'},
#  {'beckman', 'dsg4', 'menudo'},
#  {'bernina', 'hypercard', 'queloz'},
#  {'____', 'cobra', 'udel'},
#  {'aa888', 'authority', 'belief'},
#  {'extent', 'immoral', 'morality'},
#  {'pauls', 'tandy', 'trsvax'},
#  {'bible', 'faith', 'god'},
#  {'atheists', 'atterlep', 'oakland'},
#  {'chan', 'joel', 'toronto'},
#  {'buffalo', 'luke', 'ubvmsb'},
#  {'brandeis', 'cdac', 'ole'},
#  {'line', 'polygon', 'postscript'},
#  {'morris', 'team', 'viola'},
#  {'br', 'isc', 'thor'},
#  {'gene', 'jackatak', 'raider'},
#  {'mussack', 'suppose', 'universe'},
#  {'booed', 'mahogany126', 'quayle'},
#  {'nystatin', 'symptoms', 'yeast'},
#  {'bbsls23', 'volvo', 'volvos'},
#  {'harris', 'randy', 'weaver'},
#  {'amanda', 'cellular', 'feds'},
#  {'jack', 'morris', 'shawn'},
#  {'bible', 'liar', 'people'},
#  {'parcplace', 'window', 'xsizehints'},
#  {'baseball', 'espn', 'hockey'},
#  {'singer', 'unl', 'unlinfo'},
#  {'aix02', 'pilon', 'rpi'},
#  {'jesus', 'john', 'praying'},
#  {'director', 'nist', 'security'},
#  {'plugs', 'splitfire', 'splitfires'},
#  {'dean', 'nyikos', 'scarolina'},
#  {'91', 'tooltalk', 'xview'},
#  {'stein', 'thinning', 'washington'},
#  {'250', 'backup', 'tape'},
#  {'gwu', 'louray', 'seas'},
#  {'animals', 'instinctive', 'moral'},
#  {'ability', 'god', 'truth'},
#  {'1915', 'armenians', 'sdcc14'},
#  {'health', 'smokeless', 'tobacco'},
#  {'bk', 'brian', 'truck'},
#  {'ics', 'mmadsen', 'uci'},
#  {'expansion', 'leagues', 'ucdavis'},
#  {'noise', 'shos', 'unisql'},
#  {'cornell', 'kreme', 'na4'},
#  {'feldman', 'mcd', 'urbana'},
#  {'bjones', 'kevinh', 'larose'},
#  {'almo', 'ebay', 'packmind'},
#  {'language', 'spirit', 'witt'},
#  {'classes', 'federal', 'oppose'},
#  {'halat', 'minnesota', 'wisconsin'},
#  {'crash', 'henry', 'toronto'},
#  {'owner', 'photo', 'radar'},
#  {'persian', 'persians', 'rize'},
#  {'card', 'chrism', 'col'},
#  {'lopez', 'spring', 'training'},
#  {'classed', 'conductive', 'esd'},
#  {'klee', 'synoptics', 'widgets'},
#  {'00', 'dr', 'wr'},
#  {'cooper', 'rampton', 'spence'},
#  {'beretta', 'gtz', 'integra'},
#  {'_________', 'goudswaa', 'goudswaard'},
#  {'raible', 'riding', 'sf'},
#  {'banks', 'geb', 'wvnvms'},
#  {'discreet', 'pmy', 'virginia'},
#  {'ansi', 'tamu', 'tamvm1'},
#  {'rbis', 'runs', 'thf2'},
#  {'aspects', 'engin', 'split'},
#  {'86c805', 'orchid', 's3'},
#  {'1993apr18', 'ncar', 'ucar'},
#  {'event', 'expose', 'xcopyarea'},
#  {'excellent', 'geoffrey', 'tn'},
#  {'alvin', 'god', 'truth'},
#  {'perceptions', 'science', 'values'},
#  {'dortmund', 'phonetic', 'weidlich'},
#  {'armenians', 'genocide', 'turkey'},
#  {'ethic', 'infanticide', 'western'},
#  {'ccwf', 'mikey', 'utexas'},
#  {'integer', 'oz', 'packages'},
#  {'chopin', 'oldham', 'roby'},
#  {'keith', 'laws', 'livesey'},
#  {'cigarettes', 'magnus', 'ohio'},
#  {'grazing', 'scar', 'scaring'},
#  {'cd', 'fidonet', 'n106'},
#  {'callison', 'plugs', 'uoknor'},
#  {'monitor', 'nanao', 'video'},
#  {'atlantaga', 'lynx', 'ncratl'},
#  {'depression', 'factors', 'monash'},
#  {'allen', 'overhead', 'wrap'},
#  {'8323', 'henriksen', 'kurt'},
#  {'faith', 'james', 'westminster'},
#  {'credible', 'hardware', 'laurel'},
#  {'hp', 'ma90jjw', 'vcd'},
#  {'columbia', 'cunixa', 'imj1'},
#  {'imply', 'mussack', 'sin'},
#  {'bursters', 'halo', 'ns'},
#  {'ab245', 'cleveland', 'slc10'},
#  {'caltech', 'iigs', 'sunshine'},
#  {'day', 'sabbath', 'worship'},
#  {'grand', 'quad', 'v6'},
#  {'perceptions', 'science', 'values'},
#  {'advisory', 'dr', 'redesign'},
#  {'32', 'extensions', 'memory'},
#  {'latech', 'prince', 'waco'},
#  {'flyers', 'purdue', 'trade'},
#  {'bundled', 'guckes', 'sven'},
#  {'dixie', 'fbi', 'koresh'},
#  {'dyer', 'nystatin', 'yeast'},
#  {'cochrane', 'gt6511a', 'thomasp'},
#  {'nt', 'os', 'windows'},
#  {'battery', 'bmw', 'bnr'},
#  {'dewinter', 'philips', 'prl'},
#  {'cyclone', 'tempest', 'wkuvx1'},
#  {'mhz', 'speed', 'turbo'},
#  {'cable', 'caere', 'zia'},
#  {'curtis', 'howland', 'quiche'},
#  {'geoquest', 'houston', 'overpass'},
#  {'clinton', 'markets', 'tcmay'},
#  {'adam', 'fundamentalist', 'khan0095'},
#  {'asking', 'condition', 'fields'},
#  {'harris', 'hcx1', 'ssd'},
#  {'armenian', 'armenians', 'soviet'},
#  {'faqs', 'liar', 'lunatic'},
#  {'atlastele', 'hopper', 'x11r5'},
#  {'capacitor', 'fan', 'neoucom'},
#  {'code', 'debugger', 'mash'},
#  {'luis', 'paintbrush', 'scanner'},
#  {'laura', 'rpi', 'spreadsheet'},
#  {'drugs', 'ryan', 'tobacco'},
#  {'jac2y', 'tour', 'zeppelin'},
#  {'acme', 'gen', 'snooper'},
#  {'dante', 'plug', 'scsi'},
#  {'baden', 'bison', 'inqmind'},
#  {'sas', 'sasghm', 'unx'},
#  {'alaska', 'mars', 'moon'},
#  {'dodge', 'v8', 'wagon'},
#  {'baltimore', 'landis', 'stsci'},
#  {'challenges', 'charley', 'wingate'},
#  {'physicals', 'reasoning', 'topic'},
#  {'eric', 'post', 'ux1'},
#  {'bothering', 'launch', 'stdvax'},
#  {'corrupted', 'jhu', 'welch'},
#  {'beale', 'ciphers', 'crypt'},
#  {'bags', 'indiana', 'saddle'},
#  {'concealed', 'practicing', 'ucsu'},
#  {'566', 'alex', 'lisa'},
#  {'backup', 'buffalo', 'claus'},
#  {'armenia', 'island', 'onur'},
#  {'amiga', 'richg', 'sequent'},
#  {'brad', 'jake', 'sickness'},
#  {'ibm', 'nicho', 'vnet'},
#  {'boss', 'guitar', 'pedal'},
#  {'connin', 'flyers', 'rangers'},
#  {'ists', 'puck', 'replays'},
#  {'carefully', 'controlled', 'lady'},
#  {'chip', 'tuinstra', 'voice'},
#  {'fanny', 'nicholas', 'sylvain'},
#  {'aero', 'compaq', 'luke'},
#  {'banks', 'geb', 'gordon'},
#  {'hockey', 'rosters', 'star'},
#  {'alf', 'toolkit', 'virtualbinding'},
#  {'keith', 'red', 'sandvik'},
#  {'colostate', 'wallace', 'wallacen'},
#  {'foot', 'jason', 'switches'},
#  {'adelaide', 'askew', 'julius'},
#  {'blah', 's4', 'v8'},
#  {'autobahn', 'europe', 'mustang'},
#  {'amehdi', 'honeywell', 'src'},
#  {'cs1442au', 'tue', 'uta'},
#  {'marxhausen', 'nebraska', 'unl'},
#  {'b63545', 'hsc', 'sony'},
#  {'game', 'raman', 'ucsd'},
#  {'morality', 'murder', 'objective'},
#  {'imagine', 'impulse', 'replies'},
#  {'joystick', 'mcnc', 'port'},
#  {'bocher', 'trinity', 'water'},
#  {'disk', 'files', 'unix'},
#  {'clipper', 'pat', 'rwing'},
#  {'believing', 'faith', 'romans'},
#  {'capslock', 'hut', 'sami'},
#  {'glasgow', 'god', 'shaped'},
#  {'dorin', 'tough', 'unocal'},
#  {'gains', 'investors', 'tax'},
#  {'cyprus', 'esin', 'terzioglu'},
#  {'essbaum', 'ibm', 'paint'},
#  {'manager', 'parcplace', 'window'},
#  {'harley', 'levine', 'uri'},
#  {'000', 'armenia', 'armenian'},
#  {'hats', 'jake', 'propaganda'},
#  {'bsa', 'krieger', 'stan'},
#  {'keith', 'mauled', 'tiger'},
#  {'houchin', 'thouchin', 'umr'},
#  {'contradictory', 'language', 'mangoe'},
#  {'erich', 'lim', 'militech'},
#  {'2118', 'black', 'sabbath'},
#  {'israel', 'temporary', 'territories'},
#  {'europeans', 'nhl', 'rauser'},
#  {'extro', 'printers', 'ucc'},
#  {'avon', 'demon', 'mike'},
#  {'altima', 'nissan', 'spiros'},
#  {'acsu', 'buffalo', 'hammerl'},
#  {'4019', 'boise', 'slack'},
#  {'jesus', 'matthew', 'prophecy'},
#  {'electric', 'stove', 'wpi'},
#  {'collapse', 'domino', 'theory'},
#  {'baggage', 'gregg', 'jaeger'},
#  {'gayman', 'john', 'wa3wbu'},
#  {'andrew', 'hp', 'idacom'},
#  {'door', 'father', 'sumgait'},
#  {'lssu', 'peterson', 'pms'},
#  {'1986', '1987', 'survey'},
#  {'ahrens', 'bmwmoa', 'contretemps'},
#  {'aix', 'clemens', 'morris'},
#  {'brake', 'cylinder', 'master'},
#  {'crystal', 'mq', 'quartz'},
#  {'colorado', 'crary', 'russia'},
#  {'isc', 'rit', 'ultb'},
#  {'armenian', 'armenians', 'german'},
#  {'boston', 'csa', 'maxtor'},
#  {'ball', 'jeffery', 'rachford'},
#  {'canrem', 'dan', 'mckinnon'},
#  {'columbia', 'cunixa', 'methods'},
#  {'9v', 'dc', 'phakt'},
#  {'goal', 'maynard', 'puck'},
#  {'chosen', 'god', 'sandvik'},
#  {'brian', 'god', 'je'},
#  {'ncr', 'sandiego', 'tires'},
#  {'argic', 'serdar', 'varvel'},
#  {'clinic', 'doctor', 'room'},
#  {'hiram', 'hiramb', 'koutd'},
#  {'percent', 'queers', 'study'},
#  {'conceivable', 'ibmpcug', 'pem'},
#  {'canterbury', 'date', 'menu'},
#  {'bronx', 'electronics', 'trintex'},
#  {'access', 'solid', 'uwo'},
#  {'jay', 'richie', 'skidmore'},
#  {'impersonal', 'jesus', 'mussack'},
#  {'dmm', 'neoucom', 'soar'},
#  {'period', 'pp', 'scorer'},
#  {'magpie', 'manes', 'numbers'},
#  {'king', 'mo', 'vaughn'},
#  {'borland', 'guide', 'reference'},
#  {'data', 'remote', 'sensing'},
#  {'kelly', 'nosc', 'paradox'},
#  {'amendment', 'arms', 'constitution'},
#  {'cnsvax', 'nyeda', 'shy'},
#  {'dreier', 'leafs', 'spiegel'},
#  {'car', 'reed', 'rseymour'},
#  {'dialog', 'popup', 'time'},
#  {'auto', 'sho', 'stick'},
#  {'jews', 'sandvik', 'semitism'},
#  {'amoco', 'trc', 'zrdf01'},
#  {'cardinals', 'favorite', 'unl'},
#  {'chart', 'colorado', 'strip'},
#  {'caps', 'druce', 'hrivnak'},
#  {'boswell', 'rite', 'rites'},
#  {'camelot', 'dlphknob', 'protestants'},
#  {'alomar', 'pitchers', 'sandberg'},
#  {'fi', 'hut', 'jartsu'},
#  {'jb', 'placebo', 'rr'},
#  {'kirk', 'narlochn', 'wi'},
#  {'eff', 'gems', 'vcu'},
#  {'cooling', 'nuclear', 'towers'},
#  {'philistines', 'tammy', 'walla'},
#  {'daniels', 'fresco', 'neosoft'},
#  {'_mormons_', 'dividians', 'holiness'},
#  {'compuserve', 'honda', 'nathan'},
#  {'greenleaf', 'idx', 'tnx'},
#  {'hp', 'tvervaek', 'underpowered'},
#  {'deposit', 'keys', 'warlord'},
#  {'davidian', 'vay', 'yalanci'},
#  {'cwru', 'exagerate', 'wisc'},
#  {'jesus', 'josephus', 'lippard'},
#  {'greek', 'iniquity', 'judas'},
#  {'address', 'august1', 'uwindsor'},
#  {'njd', 'pgh', 'roughing'},
#  {'rochester', 'tigers', 'wynblatt'},
#  {'air', 'alaska', 'farce'},
#  {'emmons', 'holonet', 'iat'},
#  {'dartmouth', 'hades', 'mouse'},
#  {'season', 'streak', 'unbeaten'},
#  {'dayton', 'hamfest', 'hodge'},
#  {'balloons', 'preasure', 'wag'},
#  {'gak', 'stueven', 'wrs'},
#  {'ibeshir', 'nyx', 'terminal'},
#  {'anwar', 'kuwaitis', 'sarajevo'},
#  {'mouse', 'waikato', 'yale'},
#  {'banks', 'geb', 'tremor'},
#  {'kids', 'spank', 'spanking'},
#  ...]

# %%
X_tfidf.shape
# Out:
# (11314, 129794)

# %%
best_tfidf
# Out:
# [{'car', 'lerxst', 'wam'},
#  {'clock', 'poll', 'si'},
#  {'180', 'powerbook', 'purdue'},
#  {'abraxis', 'harris', 'weitek'},
#  {'bugs', 'errors', 'warning'},
#  {'destruction', 'foxvog', 'weapons'},
#  {'bmdelane', 'treatment', 'uchicago'},
#  {'10mb', 'burst', 'scsi'},
#  {'icons', 'iscsvax', 'win'},
#  {'autodoubler', 'board', 'stac'},
#  {'cmptrc', 'computrac', 'irwin'},
#  {'child', 'moral', 'parent'},
#  {'fc', 'fort', 'rod'},
#  {'flights', 'option', 'ssf'},
#  {'dryer', 'moving', 'purchased'},
#  {'mantis', 'mathew', 'trial'},
#  {'complexity', 'prestonm', 'tiff'},
#  {'car', 'insurance', 'year'},
#  {'amplifier', 'amplify', 'ritley'},
#  {'3b2', 'ncd', 'terminal'},
#  {'germany', 'keith', 'motto'},
#  {'captain', 'leafs', 'traded'},
#  {'catalog', 'rpwhite', 'scien'},
#  {'font', 'uafhp', 'window'},
#  {'loop', 'nodine', 'scsi'},
#  {'hinckley', 'onyx', 'virginia'},
#  {'nuclear', 'plants', 'water'},
#  {'arizona', 'biosci', 'joplin'},
#  {'god', 'intricate', 'wheaton'},
#  {'centerline', 'collisions', 'priorities'},
#  {'sony', 'stereo', 'theft'},
#  {'acne', 'actrix', 'teenage'},
#  {'exploding', 'ubc', 'unixg'},
#  {'arabs', 'askew', 'war'},
#  {'cipale', 'kaldis', 'rutgers'},
#  {'ists', 'mask', 'vanbiesbrouck'},
#  {'holonet', 'moa', 'static'},
#  {'amanda', 'clause', 'encryption'},
#  {'behanna', 'deductible', 'insurance'},
#  {'auto', 'revolver', 'semi'},
#  {'bonilla', 'krueger', 'schott'},
#  {'ncube', 'root', 'zod'},
#  {'digital', 'sam', 'western'},
#  {'bullpen', 'navarro', 'orosco'},
#  {'batters', 'starters', 'viola'},
#  {'152944br4416a', 'cmu', 'rb6t'},
#  {'emulator', 'iscs', 'wyse'},
#  {'csundh30', 'ers', 'movies'},
#  {'3v', '48v', 'toronto'},
#  {'18084tm', 'golden', 'space'},
#  {'failed', 'request', 'segment'},
#  {'ceremonial', 'gentile', 'sabbath'},
#  {'200', 'bj', 'canon'},
#  {'disease', 'km', 'mitchum'},
#  {'armenians', 'command', 'duke'},
#  {'crypto', 'stratus', 'sw'},
#  {'automatic', 'gear', 'throttle'},
#  {'cunyvm', 'dlmqc', 'plymouth'},
#  {'ini', 'updating', 'utility'},
#  {'cassini', 'probe', 'titan'},
#  {'blakey', 'dal', 'ug'},
#  {'msi', 'poitras', 'testing'},
#  {'cd', 'informix', 'toshiba'},
#  {'asuacad', 'cds', 'neville'},
#  {'atlanta', 'ford', 'phillips'},
#  {'infinite', 'infinity', 'tut'},
#  {'6889', 'tis', 'walker'},
#  {'atf', 'cs', 'lance'},
#  {'blask', 'religion', 'religious'},
#  {'dec', 'mattress', 'suresh'},
#  {'armenian', 'armenians', 'russian'},
#  {'callison', 'uokmax', 'uoknor'},
#  {'110vac', 'battery', 'jpl'},
#  {'aviad', 'oil', 'rdb1'},
#  {'arbor', 'bk', 'desonia'},
#  {'markz', 'ssc', 'zenier'},
#  {'key', 'phone', 'registered'},
#  {'acura', 'integra', 'miles'},
#  {'blind', 'bruno', 'windows'},
#  {'binah', 'brandeis', 'tsr'},
#  {'fatwa', 'islamic', 'rushdie'},
#  {'cameras', 'roby', 'watched'},
#  {'conference', 'csiro', 'dicta'},
#  {'0729', 'comdex', 'portal'},
#  {'eliot', 'engine', 'mr2'},
#  {'cable', 'olson', 'scsi'},
#  {'bc', 'ctrltest', 'mfc'},
#  {'dresden', 'fonts', 'gif'},
#  {'acsu', 'buffalo', 'hammerl'},
#  {'8051', 'compiliers', 'spock'},
#  {'2600', 'atari', 'impor'},
#  {'aryan', 'collaboration', 'nazi'},
#  {'cis', 'gamma', 'rubin'},
#  {'gpf', 'oracle', 'simms'},
#  {'cray', 'latech', 'speedy'},
#  {'colorado', 'cua', 'dog'},
#  {'marine', 'naval', 'reserve'},
#  {'billh', 'greed', 'huub'},
#  {'adam', 'begat', 'daughters'},
#  {'haston', 'hijaak', 'tmc'},
#  {'code', 'toolkit', 'windows'},
#  {'ericsson', 'neoucom', 'uhura'},
#  {'harleys', 'hpcc01', 'stafford'},
#  {'cbs', 'horton', 'molbio'},
#  {'anas', 'liar', 'omran'},
#  {'mhz', 'scope', 'scopes'},
#  {'decoupling', 'govindan', 'ravindran'},
#  {'balanced', 'hops', 'nasa'},
#  {'ati', 'genoa', 'pallis'},
#  {'lorne', 'sun', 'tickets'},
#  {'cramer', 'optilink', 'relationships'},
#  {'cuny', 'data', 'serial'},
#  {'controller', 'keegan', 'yale'},
#  {'breaker', 'laurentian', 'maynard'},
#  {'dan', 'holiday', 'uiuc'},
#  {'issued', 'jaeger', 'khomeini'},
#  {'dyer', 'hismanal', 'spdcc'},
#  {'amanda', 'intercon', 'nren'},
#  {'ethan', 'manager', 'window'},
#  {'doink', 'jbreed', 'pluto'},
#  {'christianity', 'god', 'sherlette'},
#  {'karr', 'mjs', 'turn'},
#  {'hades', 'pin', 'simms'},
#  {'forensic', 'listserv', 'substitution'},
#  {'hulman', 'rose', 'whitsebd'},
#  {'42', 'joachim', 'kih'},
#  {'ibm', 'n4hy', 'strom'},
#  {'guns', 'holster', 'threat'},
#  {'bradley', 'camelot', 'melido'},
#  {'hydro', 'jody', 'levine'},
#  {'amoco', 'trc', 'zmed16'},
#  {'carson', 'washington', 'weather'},
#  {'bach', 'dbase', 'iv'},
#  {'agdam', 'armenian', 'turkish'},
#  {'development', 'hlvs', 'launcher'},
#  {'crchh410', 'god', 'satan'},
#  {'jmann', 'pubs', 'stratus'},
#  {'acpub', 'north1', 'seth'},
#  {'2a42dubinski', 'csd', 'mu'},
#  {'condem', 'homosexuality', 'verses'},
#  {'anello', 'foods', 'supplements'},
#  {'182', '333', 'snf'},
#  {'24x', 'cdc', 'slc'},
#  {'encore', 'ericm', 'microunity'},
#  {'a86', 'ax', 'max'},
#  {'noring', 'quack', 'quacks'},
#  {'30am', '4679', 'video'},
#  {'invaded', 'nik', 'peace'},
#  {'apostle', 'apostles', 'fisher'},
#  {'eng', 'sysmgr', 'umd'},
#  {'sdsu', 'ucssun1', 'weston'},
#  {'brasil', 'da', 'object'},
#  {'amir', 'jews', 'land'},
#  {'maneuver', 'roll', 'shuttle'},
#  {'cpu', 'duo', 'indiana'},
#  {'brandeis', 'new', 'pip'},
#  {'car', 'insurance', 'youngblood'},
#  {'comes', 'god', 'king'},
#  {'cview', 'god', 'moscom'},
#  {'morgan', 'socs', 'technology'},
#  {'hasan', 'israel', 'water'},
#  {'57x', 'death', 'deaths'},
#  {'cindy', 'ics', 'tittle'},
#  {'noye', 'satan', 'vera'},
#  {'cubs', 'harkey', 'symantec'},
#  {'bobc', 'boeing', 'brochures'},
#  {'blazers', 'oakleys', 'purdue'},
#  {'mcdowell', 'ranger', 'ticket'},
#  {'hiram', 'package', 'refund'},
#  {'cmich', 'cmuvm', 'radio'},
#  {'cramer', 'men', 'optilink'},
#  {'linux', 'whiting', 'windows'},
#  {'cellar', 'colons', 'darling'},
#  {'kimd', 'projector', 'rpi'},
#  {'cmu', 'ofnmao_00iv1a6kyd2', 'todd'},
#  {'font', 'ti', 'xterm'},
#  {'borland', 'iastate', 'richard'},
#  {'geb', 'legal', 'tuberculosis'},
#  {'desonia', 'ibm', 'tripling'},
#  {'avery', 'blauser', 'braves'},
#  {'dubin', 'ringing', 'tinnitus'},
#  {'mprgate', 'patterson', 'rfi'},
#  {'dyer', 'paulson', 'spdcc'},
#  {'braking', 'technique', 'traction'},
#  {'assembly', 'plastic', 'tower'},
#  {'hd', 'ram', 'unimi'},
#  {'advtech', 'novak', 'uswest'},
#  {'movie', 'quicktime', 'rpi'},
#  {'garyg', 'mentorg', 'warren'},
#  {'indiana', 'kssimon', 'modem'},
#  {'ebosco', 'oracle', 'sean'},
#  {'kevin', 'mail', 'qwk'},
#  {'128', 'bits', 'keys'},
#  {'berkeley', 'industries', 'scientific'},
#  {'lowell', 'lreiter', 'tufts'},
#  {'eicn', 'perret', 'xv'},
#  {'audio', 'circuit', 'relays'},
#  {'depression', 'promiscuity', 'sex'},
#  {'destruction', 'stratus', 'weapons'},
#  {'hughes', 'ral', 'rpi'},
#  {'firearm', 'hays', 'purchased'},
#  {'10w', '10w40', '20w50'},
#  {'clamen', 'cmu', 'cs'},
#  {'illusion', 'objectively', 'reality'},
#  {'alice', 'k_p', 'key'},
#  {'baalke', 'funding', 'kelvin'},
#  {'disk', 'sdrc', 'uart'},
#  {'abbott', 'trunk', 'water'},
#  {'flyers', 'gaa', 'roussel'},
#  {'energy', 'mccall', 'perpetual'},
#  {'belief', 'beliefs', 'believe'},
#  {'cerna', 'ntep', 'tmg'},
#  {'gun', 'manes', 'rates'},
#  {'csir', 'dsp', 'za'},
#  {'accelerated', 'howtek', 'rick'},
#  {'annick', 'msg', 'physiol'},
#  {'finnegan', 'navo', 'navy'},
#  {'acme', 'apple', 'released'},
#  {'amino', 'essential', 'glutamate'},
#  {'federal', 'land', 'tax'},
#  {'arff', 'ch', 'nerone'},
#  {'blind', 'faith', 'god'},
#  {'_benson', 'fourd', 'wimp'},
#  {'0565', 'bill_paxton', 'fourd'},
#  {'fan', 'maine', 'orono'},
#  {'barreled', 'concealed', 'il'},
#  {'costly', 'dg', 'memorial'},
#  {'bnr', 'dgraham', 'semitism'},
#  {'defence', 'homicides', 'self'},
#  {'bhp', 'limit', 'vetoed'},
#  {'claussen', 'group', 'psychoactives'},
#  {'font', 'ncsu', 'window'},
#  {'alaska', 'aurora', 'henry'},
#  {'dmoney', 'stamber', 'tickets'},
#  {'defrag', 'norton', 'speedisk'},
#  {'file', 'redirect', 'servis'},
#  {'nd', 'sam', 'vma'},
#  {'centaur', 'jgreen', 'proton'},
#  {'piano', 'shapiro', 'yale'},
#  {'bryan', 'printer', 'utah'},
#  {'deon', 'scripture', 'strydom'},
#  {'henling', 'lmh', 'poland'},
#  {'140', 'aris', 'pss'},
#  {'cheng', 'd2cheng', 'dominic'},
#  {'assuring', 'escrow', 'sector'},
#  {'cheap', 'gtoal', 'phone'},
#  {'bontchev', 'hamburg', 'informatik'},
#  {'placebo', 'subjects', 'test'},
#  {'john', 'luke', 'mark'},
#  {'ftcollinsco', 'lewczyk', 'ncr'},
#  {'andover', 'mail', 'merrimack'},
#  {'arm', 'squats', 'sudden'},
#  {'engin', 'ingles', 'tortured'},
#  {'graders', 'lsd', 'marijuana'},
#  {'dct', 'greig', 'mcs'},
#  {'ini', 'notepad', 'sysedit'},
#  {'brewer', 'fanning', 'lib'},
#  {'access', 's1', 's2'},
#  {'better', 'rookie', 'year'},
#  {'esdi', 'ide', 'ivan'},
#  {'aids', 'lenient', 'sex'},
#  {'bases', 'clinton', 'seawolf'},
#  {'keys', 'pockets', 'women'},
#  {'agreement', 'pirates', 'simmons'},
#  {'alaska', 'prize', 'small'},
#  {'k_mullin', 'mully', 'plymouth'},
#  {'oilers', 'podein', 'rangers'},
#  {'000', 'israel', 'killed'},
#  {'ncr', 'orwig', 'shaft'},
#  {'dia', 'nemo', 'upm'},
#  {'card', 'glenn', 'rmit'},
#  {'cwru', 'po', 'quattro'},
#  {'aura', 'neurologic', 'zisfein'},
#  {'101', 'berger', 'brandeis'},
#  {'centerline', 'cup', 'jimf'},
#  {'es', 'imp', 'sim'},
#  {'bits', 'key', 'silverton'},
#  {'gcohen', 'ncube', 'scanner'},
#  {'cmwolf', 'electronics', 'willisw'},
#  {'approved', 'gtoal', 'modems'},
#  {'berkeley', 'mpc', 'rom'},
#  {'kuleuven', 'leuven', 'liris'},
#  {'dseg', 'pyron', 'ti'},
#  {'box', 'jay', 'skidmore'},
#  {'rayshade', 'rle', 'washington'},
#  {'batteries', 'freenet', 'michel'},
#  {'eff', 'heh', 'rita'},
#  {'assumption', 'jung', 'mary'},
#  {'aquinas', 'kuhub', 'miner'},
#  {'desc', 'laptop', 'toshiba'},
#  {'colormap', 'cursor', 'dialogshell'},
#  {'george', 'gp2011', 'matt'},
#  {'discovery', 'sun', 'uk'},
#  {'950', 'case', 'quadra'},
#  {'aluminum', 'ammunition', 'mtu'},
#  {'israeli', 'questions', 'true'},
#  {'dodgers', 'ingres', 'la'},
#  {'pb2esac', 'rider', 'tank'},
#  {'ice', 'octopus', 'symbolism'},
#  {'jews', 'land', 'zbib'},
#  {'giveaways', 'night', 'sponser'},
#  {'arms', 'bear', 'holland'},
#  {'cornell', 'shaft', 'virago'},
#  {'church', 'coptic', 'monophysitism'},
#  {'magnus', 'scalpers', 'tickets'},
#  {'040', 'ameres', 'powerpc'},
#  {'compilers', 'csir', 'za'},
#  {'click', 'whirr', 'whirrr'},
#  {'gc', 'gxxor', 'mydisplay'},
#  {'grayscale', 'mac', 'wyvern'},
#  {'judge', 'kmr4', 'tammy'},
#  {'cutter', 'gloster', 'nc'},
#  {'birthday', 'happy', 'israel'},
#  {'nilay', 'nilayp', 'tapes'},
#  {'parts', 'robie', 'umbc'},
#  {'keith', 'motto', 'religion'},
#  {'creation', 'susan', 'uchicago'},
#  {'ch981', 'cleveland', 'tony'},
#  {'bb', 'ddd', 'sscl'},
#  {'kv07', 'vonroeschlaub', 'warren'},
#  {'hopper', 'r5', 'sony'},
#  {'concert', 'courter', 'naomi'},
#  {'henry', 'hst', 'reboost'},
#  {'nhl', 'pick', 'viktor'},
#  {'lemons', 'x11r6', 'xremote'},
#  {'archiving', 'concert', 'warrant'},
#  {'hare', 'tripp', 'tuscon'},
#  {'bedroom', 'condo', 'room'},
#  {'_______________________________', 'joachim', 'kih'},
#  {'bone', 'sacrum', 'vertebrae'},
#  {'chen', 'col', 'msg'},
#  {'optilink', 'parade', 'walsh'},
#  {'columbia', 'cunixa', 'marc'},
#  {'filenames', 'hfeldman', 'howard'},
#  {'002251w', 'abbot', 'acadiau'},
#  {'brunel', 'cs89mcd', 'uk'},
#  {'bmp', 'gif', 'scott'},
#  {'cactus', 'joe', 'rider'},
#  {'aardvark', 'chihuahua', 'uoknor'},
#  {'charles', 'emmons', 'trintex'},
#  {'brown', 'leo', 'unm'},
#  {'breathing', 'chest', 'liquid'},
#  {'analog', 'willie', 'wilson'},
#  {'cost', 'henry', 'launch'},
#  {'rochester', 'times_', 'wycliffe'},
#  {'clubs', 'kc', 'waivers'},
#  {'com1', 'howtek', 'phil'},
#  {'aid', 'conservatives', 'julie'},
#  {'flipping', 'massey', 'vga'},
#  {'berkeley', 'methodologically', 'mow'},
#  {'espn', 'florida', 'playoffs'},
#  {'electric', 'fields', 'unocal'},
#  {'bskendig', 'creation', 'kendig'},
#  {'jmc', 'mccarthy', 'stanford'},
#  {'christianity', 'haefner', 'mwhaefne'},
#  {'c5r7tv', 'kubey', 'sgi'},
#  {'colostate', 'level', 'wallacen'},
#  {'austin', 'ibm', 'leapman'},
#  {'mac', 'meg', 'motorola'},
#  {'lucifer', 'satan', 'theology'},
#  {'neale', 'pioneer', 'rochester'},
#  {'tax', 'vat', 'veal'},
#  {'cook', 'layne', 'mdc'},
#  {'hubble', 'observations', 'uranus'},
#  {'bony1', 'jake', 'livni'},
#  {'acne', 'clearasil', 'teenage'},
#  {'father', 'son', 'spirit'},
#  {'intel', 'motif', 'x11r5'},
#  {'aero', 'aerospace', 'lau'},
#  {'descartes', 'etl', 'riggs'},
#  {'cri', 'grace', 'nz'},
#  {'cartlidge', 'cs1442aq', 'inhis'},
#  {'00', '15', 'magazine'},
#  {'abc', 'plane', 'sphere'},
#  {'rvenkate', 'simms', 'venkateswar'},
#  {'card', 'ega', 'maine'},
#  {'adobe', 'cjackson', 'db'},
#  {'occam', 'okcforum', 'razor'},
#  {'kurds', 'soviet', 'turks'},
#  {'2322', 'berlin', 'stefan'},
#  {'serc', 'shadow', 'uk'},
#  {'cramer', 'fetishes', 'immoral'},
#  {'bears', 'national', 'psychos'},
#  {'condoms', 'dak988s', 'president'},
#  {'edmondson', 'qmw', 'rr'},
#  {'corn', 'paulson', 'uga'},
#  {'betts', 'displays', 'lcd'},
#  {'atheists', 'death', 'hell'},
#  {'asphaug', 'erik', 'zephyr'},
#  {'mark', 'ocs', 'ocsmd'},
#  {'mathew', 'morality', 'objective'},
#  {'kuiper', 'nicoll', 'smiley'},
#  {'mac', 'sdchemw2', 'stereo'},
#  {'behr', 'cable', 'ilstu'},
#  {'columbia', 'cunixb', 'freeman'},
#  {'color', 'default', 'xterm'},
#  {'deal', 'hes', 'return'},
#  {'grape', 'nswses', 'subscribe'},
#  {'cilia', 'pediatrician', 'syndrome'},
#  {'hsieh', 'julia', 'micron'},
#  {'andy', 'clipper', 'hooper'},
#  {'ferguson', 'george', 'rochester'},
#  {'josephson', 'microphone', 'nyu'},
#  {'mulvey', 'oswego', 'wpi'},
#  {'france', 'nuclear', 'towers'},
#  {'antonio', 'balsamo', 'stargl'},
#  {'detroit', 'mtroyal', 'riel'},
#  {'durham', 'ellis', 'uk'},
#  {'cobb', 'kevin', 'morality'},
#  {'pov', 'tamsun', 'tga'},
#  {'ibm', 'lethal', 'mjp'},
#  {'bytes', 'filemanager', 'select'},
#  {'geoff', 'kuenning', 'ucla'},
#  {'markz', 'musone', 'ssc'},
#  {'manu', 'oas', 'olivetti'},
#  {'_____', 'bombed', 'centerline'},
#  {'fish', 'tvtwm', 'vanderpool'},
#  {'karen', 'westford', 'xtici'},
#  {'harmons', 'rein', 'sommer'},
#  {'selections', 'wolfram', 'wri'},
#  {'davpa', 'ida', 'partain'},
#  {'abstinence', 'education', 'pregnancy'},
#  {'marriage', 'priest', 'required'},
#  {'17', 'msstate', 'pork'},
#  {'caltech', 'chimps', 'keith'},
#  {'_____',
#   '__________________________________________________________________________',
#   'characterization'},
#  {'906', 'akerman', 'doug'},
#  {'circuit', 'screen', 'verity'},
#  {'xie', 'zhihua', 'zxxst'},
#  {'alec', 'alee', 'font'},
#  {'720', 'hpwala', 'limagen'},
#  {'battery', 'draining', 'recharge'},
#  {'aide', 'hit', 'space'},
#  {'bontchev', 'hamburg', 'informatik'},
#  {'greg', 'ratings', 'webo'},
#  {'albany', 'ls8139', 'silverberg'},
#  {'apostasy', 'khomeini', 'rushdie'},
#  {'logo', 'mask', 'pens'},
#  {'graphite', 'metrics', 'tomh'},
#  {'andrea', 'sto', 'winkler'},
#  {'iaserv', 'ingr', 'tcsteven'},
#  {'buffalo', 'captain', 'traded'},
#  {'african', 'jesus', 'semitic'},
#  {'iupui', 'libya', 'stop'},
#  {'bourke', 'christi', 'liturgy'},
#  {'manta', 'opel', 'uiuc'},
#  {'cable', 'lock', 'steel'},
#  {'database', 'escrow', 'exabyte'},
#  {'_true', 'fisher', 'indiana'},
#  {'3r6', 'onions', 'std'},
#  {'408', '448', 'clock'},
#  {'klinger', 'umanitoba', 'wave'},
#  {'funding', 'henry', 'spacecraft'},
#  {'hasan', 'israel', 'water'},
#  {'caronni', 'germano', 'key'},
#  {'hahn', 'spot', 'uwm'},
#  {'csl', 'nra', 'strait'},
#  {'iastate', 'justin', 'party'},
#  {'destruction', 'eternal', 'hell'},
#  {'deltabox', 'frame', 'klinger'},
#  {'jayne', 'kulikauskas', 'patiently'},
#  {'carb', 'convex', 'screws'},
#  {'marshatt', 'purdue', 'zauberer'},
#  {'csd4', 'qazi', 'uwm'},
#  {'equinox', 'hats', 'vinyl'},
#  {'bezier', 'ferdinand', 'oeinck'},
#  {'button', 'horn', 'throttle'},
#  {'challenger', 'software', 'wingert'},
#  {'contrary', 'evidence', 'virgilio'},
#  {'andi', 'hamaza', 'jake'},
#  {'jorge', 'sun', 'typewriter'},
#  {'kings', 'melrose', 'stauber'},
#  {'behunin', 'games', 'mdt'},
#  {'biggest', 'player', 'savard'},
#  {'gatech', 'matthew', 'ryukoku'},
#  {'adam', 'rivers', 'sea'},
#  {'blessed', 'forgiven', 'sins'},
#  {'hindered', 'jayne', 'prayer'},
#  {'hanlan', 'keithh', 'motorcycling'},
#  {'0114', 'demers', 'ucsd'},
#  {'behaviour', 'morality', 'natural'},
#  {'amitriptyline', 'banks', 'geb'},
#  {'gm', 'murray', 'uvic'},
#  {'386sx', 'controller', 'settings'},
#  {'house', 'lords', 'senate'},
#  {'memory', 'tamu', 'upper'},
#  {'harley', 'request', 'thinkage'},
#  {'lm', 'margoli', 'violation'},
#  {'fenway', 'rpi', 'umassd'},
#  {'duo', 'fung', 'ram'},
#  {'hays', 'raid', 'sheriff'},
#  {'argument', 'argumentum', 'fallacy'},
#  {'gm', 'gmr', 'toyota'},
#  {'shite', 'sinkhole', 'xgolf'},
#  {'hockey', 'maynard', 'playoff'},
#  {'okcforum', 'omnipotence', 'rules'},
#  {'a137490', 'aario', 'tut'},
#  {'grow', 'lingers', 'wacky'},
#  {'m0', 'm9', 'mv'},
#  {'lawn', 'mower', 'riding'},
#  {'kaist', 'kr', 'rtf'},
#  {'computer', 'gets', 'locked'},
#  {'det', 'leads', 'shots'},
#  {'greece', 'greek', 'turkish'},
#  {'acid', 'amino', 'glutamate'},
#  {'batf', 'cdt', 'stratus'},
#  {'127', 'byte', 'rgb'},
#  {'andi', 'palestinians', 'suffered'},
#  {'ad', 'dan', 'portal'},
#  {'force', 'islam', 'islamic'},
#  {'cook', 'enzo', 'sky'},
#  {'drive', 'jester', 'michael'},
#  {'apple', 'hades', 'simms'},
#  {'_________', 'exe', 'goudswaard'},
#  {'caron', 'gun', 'restraining'},
#  {'actix', 'eecg', 'wongda'},
#  {'144', '28', 'mvp'},
#  {'3d', 'msstate', 'trb3'},
#  {'rcs8', 'sprecher', 'syquest'},
#  {'altitude', 'cities', 'mdavcr'},
#  {'amoco', 'johnh', 'simms'},
#  {'3fgx', 'nec', 'umass'},
#  {'beam', 'col', 'crow'},
#  {'absolute', 'absolutes', 'mistakes'},
#  {'constantinople', 'empire', 'sack'},
#  {'game', 'games', 'snes'},
#  {'odometer', 'pulses', 'scn'},
#  {'diamond', 'hartmann', 'lance'},
#  {'exhaust', 'intake', 'pressure'},
#  {'mankind', 'moral', 'morality'},
#  {'borland', 'libraries', 's3'},
#  {'debugger', 'turbo', 'video'},
#  {'dlo', 'hunting', 'ifas'},
#  {'canon', 'enzo', 'nasa'},
#  {'ncr', 'options', 'sandiego'},
#  {'tektronix', 'tv', 'tvi'},
#  {'anas', 'liar', 'omran'},
#  {'knots', 'ri', 'vi'},
#  {'jed', 'pollux', 'usc'},
#  {'herzog', 'sparcclassic', 'sunsoft'},
#  {'clemens', 'meaddata', 'sox'},
#  {'css', 'itd', 'sweda'},
#  {'heath', 'masculine', 'unbalanced'},
#  {'23064rfl', 'testing', 'utk'},
#  {'2600', 'mycal', 'netacsys'},
#  {'astronaut', 'nasa', 'pilot'},
#  {'cin', 'davis', 'lynch'},
#  {'engine', 'mr2', 'noisy'},
#  {'440mhz', 'anomaly', 'der'},
#  {'dub', 'sunday', 'willing'},
#  {'tyng', 'yih', 'ytwu'},
#  {'importance', 'meaning', 'mussack'},
#  {'mcluhan', 'siggraph', 'toronto'},
#  {'ford', 'slee01', 'srl'},
#  {'adjective', 'king', 'kyle'},
#  {'bla', 'null', 'widget'},
#  {'israel', 'naftaly', 'nstramer'},
#  {'produced', 'property', 'savages'},
#  {'abyss', 'breathing', 'liquid'},
#  {'lmsc', 'lockheed', 'slagle'},
#  {'factoring', 'kl', 'neuhaus'},
#  {'earle', 'isolar', 'twm'},
#  {'eisa', 'korenek', 'motherboard'},
#  {'alaa', 'naftaly', 'zeineldine'},
#  {'csd4', 'qazi', 'uwm'},
#  {'den', 'p2', 'p3'},
#  {'aids', 'sin', 'ttt'},
#  {'1x', 'ae', 'ep'},
#  {'heriot', 'printer', 'stuart'},
#  {'images', 'ruu', 'unocal'},
#  {'ide', 'kepler', 'unh'},
#  {'armenian', 'armenians', 'sumgait'},
#  {'catholic', 'church', 'liturgy'},
#  {'hydro', 'jody', 'levine'},
#  {'kaldis', 'rolla', 'umr'},
#  {'cfaehl', 'itc', 'vesta'},
#  {'desktop', 'holding', 'rebuild'},
#  {'agr00', 'amdahl', 'sandvik'},
#  {'bios', 'motherboard', 'ncd'},
#  {'18084tm', 'billion', 'space'},
#  {'keith', 'lions', 'moral'},
#  {'400', 'bgardner', 'twin'},
#  {'3352', 'bnr', 'uk'},
#  {'period', 'pp', 'scorer'},
#  {'imag', 'linux', 'schaefer'},
#  {'elin', 'rainer', 'server'},
#  {'mattingly', 'skeptical', 'snow'},
#  {'asked', 'chloupek', 'ohio'},
#  {'eds', 'jan', 'vandenbrande'},
#  {'change', 'keele', 'licensed'},
#  {'hudson', 'immoral', 'pain'},
#  {'concealed', 'law', 'officials'},
#  {'bgu', 'vent', 'windows'},
#  {'cryptography', 'harvard', 'kubo'},
#  {'dortmund', 'phonetic', 'weidlich'},
#  {'click', 'whirr', 'whirrr'},
#  {'chad', 'lehigh', 'ungo'},
#  {'beckman', 'pkp', 'rsa'},
#  {'60', 'loral', 'mile'},
#  {'doug', 'drivers', 'stealth'},
#  {'barbara', 'gifford', 'paradox'},
#  {'ncr', 'thompson', 'tvi'},
#  {'geo', 'neo', 'tomcat'},
#  {'ohio', 'oil', 'ubc'},
#  {'bob', 'subliminal', 'tv'},
#  {'72', 'aust', 'townsville'},
#  {'liverpool', 'spss', 'wooff'},
#  {'452', 'comp', 'russ'},
#  {'arena', 'mall', 'neoucom'},
#  {'accelerations', 'amruth', 'laxman'},
#  {'amit', 'open', 'yali'},
#  {'harding', 'nunnally', 'sandvik'},
#  {'food', 'lundby', 'msg'},
#  {'arndt', 'comic', 'gac'},
#  {'absolute', 'absolutes', 'truth'},
#  {'halat', 'mathew', 'train'},
#  {'chris', 'memphis', 'virginia'},
#  {'550', 'elef', 'smarmy'},
#  {'shaft', 'stafford', 'wheelies'},
#  {'aedc', 'csiro', 'gooch'},
#  {'howard', 'moy', 'near'},
#  {'cybernet', 'rocks', 'vlasis'},
#  {'kevin', 'purdue', 'stamber'},
#  {'gxxor', 'rectangle', 'rectangles'},
#  {'lee', 'sv', 'tosspot'},
#  {'indiana', 'nate', 'psych'},
#  {'centrifuge', 't343', 'youd'},
#  {'gl', 'pyeatt', 'texaco'},
#  {'com', 'dec', 'portal'},
#  {'brian', 'ceccarelli', 'lpl'},
#  {'apple', 'meg', 'simms'},
#  {'differential', 'lane', 'startled'},
#  {'parc', 'sale', 'xerox'},
#  {'ching', 'fledgling', 'wpi'},
#  {'karma', 'lives', 'reincarnation'},
#  {'milligan', 'nancy', 'rude'},
#  {'cylinder', 'joni', 'master'},
#  {'art', 'cbnewsh', 'martial'},
#  {'dsc', 'gemini', 'gsfc'},
#  {'curves', 'detecting', 'oeinck'},
#  {'cardhu', 'dominik', 'dundee'},
#  {'dak988s', 'smsu', 'vma'},
#  {'gay', 'homosexual', 'men'},
#  {'brian', 'jesus', 'john'},
#  {'attacks', 'civilians', 'israel'},
#  {'68040', 'lazer', 'wpi'},
#  {'chevron', 'nosebleeds', 'zalan'},
#  {'floggings', 'orient', 'sex'},
#  {'ico', 'okcforum', 'osrhe'},
#  {'fbi', 'gas', 'koresh'},
#  {'ata', 'hfsi', 'jesus'},
#  {'manu', 'siblings', 'ws_thickframe'},
#  {'rand', 'tubes', 'uv'},
#  {'dolven', 'doug', 'montana'},
#  {'csuchico', 'ecst', 'resource'},
#  {'jt', 'magnus', 'ohio'},
#  {'innocent', 'murder', 'objective'},
#  {'bear', 'noaa', 'search'},
#  {'armenia', 'soviet', 'turkish'},
#  {'car', 'km', 'maxima'},
#  {'brocku', 'spartan', 'tmc'},
#  {'grant', 'totten', 'trentu'},
#  {'bus', 'ide', 'sec'},
#  {'geb', 'rebound', 'weight'},
#  {'fielding', 'robinson', 'santo'},
#  {'584', '611', '616'},
#  {'colorado', 'davewood', 'rockies'},
#  {'mccoy', 'xterm', 'xterms'},
#  {'atlantaga', 'ncr', 'unpatriotic'},
#  {'cubs', 'era', 'guzman'},
#  {'br', 'isc', 'libertarians'},
#  {'alomar', 'baerga', 'eskimo'},
#  {'belvedere', 'gatech', 'prism'},
#  {'kkk', 'passe', 'rkba'},
#  {'assistance', 'economic', 'palestinian'},
#  {'ini', 'svein', 'updating'},
#  {'integra', 'ls', 'peng'},
#  {'duke', 'ipx', 'ndd'},
#  {'256', 'hardy', 'washington'},
#  {'cbnewsl', 'islanders', 'mcgill'},
#  {'1d7', 'mike', 'umn'},
#  {'claremont', 'gospel', 'origins_'},
#  {'89', 'trunk', 'water'},
#  {'cannucks', 'grogers', 'slacvx'},
#  {'blah', 'halat', 'islam'},
#  {'bios', 'date', 'wrap'},
#  {'cciw', 'csx', 'ulowell'},
#  {'government', 'turkish', 'usenet'},
#  {'dishonest', 'ncr', 'wilson'},
#  {'anger', 'angry', 'emotions'},
#  {'caltech', 'ico', 'keith'},
#  {'israel', 'israeli', 'nazis'},
#  {'devil', 'jah', 'man'},
#  {'6mb', 'file', 'w4w'},
#  {'clipper', 'fairchild', 'intergraph'},
#  {'rogers', 'tesla', 'underwater'},
#  {'grahm', 'increases', 'technet'},
#  {'extant', 'slac', 'stanford'},
#  {'brocku', 'spartan', 'tmc'},
#  {'dunn', 'phones', 'roofs'},
#  {'files', 'jpg', 'otis'},
#  {'250', 'henson', 'ninja'},
#  {'bits', 'block', 'wiretap'},
#  {'kidney', 'stones', 'wvnvms'},
#  {'isc', 'rit', 'ritvax'},
#  {'cramer', 'fogarty', 'professors'},
#  {'drawindex', 'mydisplay', 'palette_colors'},
#  {'human', 'jesus', 'nestorius'},
#  {'existance', 'mwm', 'stefan'},
#  {'images', 'pixel', 'weber'},
#  {'grissom', 'number', 'operator'},
#  {'hdf', 'markus', 'octavia'},
#  {'beckman', 'dsg4', 'menudo'},
#  {'bernina', 'hypercard', 'queloz'},
#  {'____', 'cobra', 'udel'},
#  {'aa888', 'authority', 'belief'},
#  {'extent', 'immoral', 'morality'},
#  {'pauls', 'tandy', 'trsvax'},
#  {'bible', 'faith', 'god'},
#  {'atheists', 'atterlep', 'oakland'},
#  {'chan', 'joel', 'toronto'},
#  {'buffalo', 'luke', 'ubvmsb'},
#  {'brandeis', 'cdac', 'ole'},
#  {'line', 'polygon', 'postscript'},
#  {'morris', 'team', 'viola'},
#  {'br', 'isc', 'thor'},
#  {'gene', 'jackatak', 'raider'},
#  {'mussack', 'suppose', 'universe'},
#  {'booed', 'mahogany126', 'quayle'},
#  {'nystatin', 'symptoms', 'yeast'},
#  {'bbsls23', 'volvo', 'volvos'},
#  {'harris', 'randy', 'weaver'},
#  {'amanda', 'cellular', 'feds'},
#  {'jack', 'morris', 'shawn'},
#  {'bible', 'liar', 'people'},
#  {'parcplace', 'window', 'xsizehints'},
#  {'baseball', 'espn', 'hockey'},
#  {'singer', 'unl', 'unlinfo'},
#  {'aix02', 'pilon', 'rpi'},
#  {'jesus', 'john', 'praying'},
#  {'director', 'nist', 'security'},
#  {'plugs', 'splitfire', 'splitfires'},
#  {'dean', 'nyikos', 'scarolina'},
#  {'91', 'tooltalk', 'xview'},
#  {'stein', 'thinning', 'washington'},
#  {'250', 'backup', 'tape'},
#  {'gwu', 'louray', 'seas'},
#  {'animals', 'instinctive', 'moral'},
#  {'ability', 'god', 'truth'},
#  {'1915', 'armenians', 'sdcc14'},
#  {'health', 'smokeless', 'tobacco'},
#  {'bk', 'brian', 'truck'},
#  {'ics', 'madsen', 'mmadsen'},
#  {'expansion', 'leagues', 'ucdavis'},
#  {'noise', 'shos', 'unisql'},
#  {'cornell', 'kreme', 'na4'},
#  {'feldman', 'mcd', 'urbana'},
#  {'ascom', 'hasler', 'kevinh'},
#  {'almo', 'ebay', 'packmind'},
#  {'language', 'spirit', 'witt'},
#  {'classes', 'federal', 'oppose'},
#  {'halat', 'minnesota', 'wisconsin'},
#  {'crash', 'henry', 'toronto'},
#  {'owner', 'photo', 'radar'},
#  {'persian', 'persians', 'rize'},
#  {'card', 'chrism', 'col'},
#  {'lopez', 'spring', 'training'},
#  {'classed', 'conductive', 'esd'},
#  {'klee', 'synoptics', 'widgets'},
#  {'00', 'dr', 'wr'},
#  {'cooper', 'rampton', 'spence'},
#  {'beretta', 'gtz', 'integra'},
#  {'_________', 'goudswaa', 'goudswaard'},
#  {'raible', 'riding', 'sf'},
#  {'banks', 'geb', 'wvnvms'},
#  {'pmy', 'virginia', 'yadlowsky'},
#  {'ansi', 'tamu', 'tamvm1'},
#  {'rbis', 'runs', 'thf2'},
#  {'aspects', 'engin', 'umich'},
#  {'86c805', 'orchid', 's3'},
#  {'1993apr18', 'ncar', 'ucar'},
#  {'buzz', 'event', 'expose'},
#  {'excellent', 'geoffrey', 'tn'},
#  {'alvin', 'god', 'truth'},
#  {'perceptions', 'science', 'values'},
#  {'dortmund', 'phonetic', 'weidlich'},
#  {'armenians', 'genocide', 'turkey'},
#  {'ethic', 'infanticide', 'western'},
#  {'ccwf', 'mikey', 'utexas'},
#  {'integer', 'oz', 'packages'},
#  {'chopin', 'oldham', 'roby'},
#  {'keith', 'laws', 'livesey'},
#  {'cigarettes', 'magnus', 'ohio'},
#  {'grazing', 'scar', 'scaring'},
#  {'1701', 'cd', 'n106'},
#  {'callison', 'plugs', 'uoknor'},
#  {'monitor', 'nanao', 'video'},
#  {'atlantaga', 'lynx', 'ncratl'},
#  {'depression', 'factors', 'monash'},
#  {'allen', 'overhead', 'wrap'},
#  {'8323', 'henriksen', 'kurt'},
#  {'faith', 'james', 'westminster'},
#  {'credible', 'hardware', 'laurel'},
#  {'hp', 'ma90jjw', 'vcd'},
#  {'imad', 'imj1', 'jureidini'},
#  {'imply', 'mussack', 'sin'},
#  {'bursters', 'colliding', 'ns'},
#  {'ab245', 'cleveland', 'latonia'},
#  {'caltech', 'iigs', 'sunshine'},
#  {'day', 'sabbath', 'worship'},
#  {'grand', 'quad', 'v6'},
#  {'perceptions', 'science', 'values'},
#  {'advisory', 'dr', 'redesign'},
#  {'32', 'extensions', 'memory'},
#  {'latech', 'prince', 'waco'},
#  {'flyers', 'purdue', 'trade'},
#  {'bundled', 'guckes', 'sven'},
#  {'dixie', 'fbi', 'koresh'},
#  {'dyer', 'nystatin', 'yeast'},
#  {'cochrane', 'gt6511a', 'parsli'},
#  {'nt', 'os', 'windows'},
#  {'battery', 'bmw', 'bnr'},
#  {'dewinter', 'philips', 'prl'},
#  {'cyclone', 'tempest', 'wkuvx1'},
#  {'mhz', 'speed', 'turbo'},
#  {'cable', 'caere', 'zia'},
#  {'curtis', 'howland', 'quiche'},
#  {'geoquest', 'houston', 'overpass'},
#  {'clinton', 'markets', 'tcmay'},
#  {'adam', 'fundamentalist', 'khan0095'},
#  {'asking', 'condition', 'fields'},
#  {'harris', 'hcx1', 'ssd'},
#  {'armenian', 'armenians', 'soviet'},
#  {'faqs', 'liar', 'lunatic'},
#  {'atlastele', 'hopper', 'x11r5'},
#  {'capacitor', 'fan', 'neoucom'},
#  {'code', 'debugger', 'mash'},
#  {'luis', 'paintbrush', 'scanner'},
#  {'laura', 'rpi', 'spreadsheet'},
#  {'drugs', 'ryan', 'tobacco'},
#  {'jac2y', 'tour', 'zeppelin'},
#  {'acme', 'gen', 'snooper'},
#  {'dante', 'plug', 'scsi'},
#  {'baden', 'bison', 'inqmind'},
#  {'sas', 'sasghm', 'theseus'},
#  {'alaska', 'mars', 'moon'},
#  {'dodge', 'v8', 'wagon'},
#  {'baltimore', 'landis', 'stsci'},
#  {'challenges', 'charley', 'wingate'},
#  {'physicals', 'reasoning', 'topic'},
#  {'eric', 'post', 'ux1'},
#  {'bothering', 'launch', 'stdvax'},
#  {'corrupted', 'jhu', 'welch'},
#  {'beale', 'ciphers', 'crypt'},
#  {'bags', 'indiana', 'saddle'},
#  {'concealed', 'practicing', 'ucsu'},
#  {'566', 'alex', 'lisa'},
#  {'backup', 'buffalo', 'claus'},
#  {'island', 'onur', 'yalcin'},
#  {'amiga', 'richg', 'sequent'},
#  {'brad', 'jake', 'sickness'},
#  {'ibm', 'nicho', 'vnet'},
#  {'boss', 'guitar', 'pedal'},
#  {'connin', 'flyers', 'rangers'},
#  {'ists', 'puck', 'replays'},
#  {'carefully', 'controlled', 'lady'},
#  {'chip', 'tuinstra', 'voice'},
#  {'fanny', 'nicholas', 'sylvain'},
#  {'aero', 'compaq', 'luke'},
#  {'banks', 'geb', 'gordon'},
#  {'hockey', 'rosters', 'star'},
#  {'alf', 'toolkit', 'virtualbinding'},
#  {'keith', 'red', 'sandvik'},
#  {'colostate', 'wallace', 'wallacen'},
#  {'foot', 'jason', 'switches'},
#  {'adelaide', 'askew', 'julius'},
#  {'blah', 's4', 'v8'},
#  {'autobahn', 'europe', 'mustang'},
#  {'amehdi', 'honeywell', 'src'},
#  {'cs1442au', 'tue', 'uta'},
#  {'marxhausen', 'nebraska', 'unl'},
#  {'b63545', 'hsc', 'sony'},
#  {'game', 'raman', 'ucsd'},
#  {'morality', 'murder', 'objective'},
#  {'imagine', 'impulse', 'replies'},
#  {'joystick', 'mcnc', 'port'},
#  {'bocher', 'trinity', 'water'},
#  {'disk', 'files', 'unix'},
#  {'clipper', 'pat', 'rwing'},
#  {'believing', 'faith', 'romans'},
#  {'capslock', 'hut', 'sami'},
#  {'glasgow', 'god', 'shaped'},
#  {'dorin', 'tough', 'unocal'},
#  {'gains', 'investors', 'tax'},
#  {'cyprus', 'esin', 'terzioglu'},
#  {'essbaum', 'ibm', 'paint'},
#  {'manager', 'parcplace', 'window'},
#  {'harley', 'levine', 'uri'},
#  {'000', 'armenia', 'armenian'},
#  {'hats', 'jake', 'propaganda'},
#  {'bsa', 'krieger', 'stan'},
#  {'keith', 'mauled', 'tiger'},
#  {'houchin', 'thouchin', 'umr'},
#  {'contradictory', 'language', 'mangoe'},
#  {'erich', 'lim', 'militech'},
#  {'black', 'oughta', 'sabbath'},
#  {'israel', 'temporary', 'territories'},
#  {'europeans', 'nhl', 'rauser'},
#  {'extro', 'printers', 'ucc'},
#  {'avon', 'demon', 'mike'},
#  {'altima', 'nissan', 'spiros'},
#  {'acsu', 'buffalo', 'hammerl'},
#  {'4019', 'boise', 'slack'},
#  {'jesus', 'matthew', 'prophecy'},
#  {'electric', 'stove', 'wpi'},
#  {'collapse', 'domino', 'theory'},
#  {'baggage', 'gregg', 'jaeger'},
#  {'gayman', 'john', 'wa3wbu'},
#  {'andrew', 'hp', 'idacom'},
#  {'door', 'father', 'sumgait'},
#  {'lssu', 'peterson', 'pms'},
#  {'1986', '1987', 'survey'},
#  {'ahrens', 'bmwmoa', 'contretemps'},
#  {'aix', 'clemens', 'morris'},
#  {'brake', 'cylinder', 'master'},
#  {'crystal', 'mq', 'quartz'},
#  {'colorado', 'crary', 'russia'},
#  {'isc', 'rit', 'ultb'},
#  {'armenian', 'armenians', 'german'},
#  {'boston', 'csa', 'maxtor'},
#  {'ball', 'jeffery', 'rachford'},
#  {'canrem', 'dan', 'mckinnon'},
#  {'columbia', 'cunixa', 'methods'},
#  {'9v', 'dc', 'phakt'},
#  {'goal', 'maynard', 'puck'},
#  {'chosen', 'god', 'sandvik'},
#  {'brian', 'god', 'je'},
#  {'ncr', 'sandiego', 'tires'},
#  {'argic', 'serdar', 'varvel'},
#  {'clinic', 'doctor', 'room'},
#  {'hiram', 'hiramb', 'kou'},
#  {'percent', 'queers', 'study'},
#  {'conceivable', 'ibmpcug', 'pem'},
#  {'canterbury', 'date', 'menu'},
#  {'bronx', 'electronics', 'trintex'},
#  {'access', 'solid', 'uwo'},
#  {'jay', 'skidmore', 'traveled'},
#  {'impersonal', 'jesus', 'mussack'},
#  {'dmm', 'neoucom', 'soar'},
#  {'period', 'pp', 'scorer'},
#  {'linknet', 'magpie', 'manes'},
#  {'king', 'mo', 'vaughn'},
#  {'borland', 'guide', 'reference'},
#  {'data', 'remote', 'sensing'},
#  {'kelly', 'nosc', 'paradox'},
#  {'amendment', 'arms', 'constitution'},
#  {'cnsvax', 'nyeda', 'shy'},
#  {'dreier', 'leafs', 'spiegel'},
#  {'car', 'reed', 'rseymour'},
#  {'dialog', 'popup', 'time'},
#  {'auto', 'sho', 'stick'},
#  {'jews', 'sandvik', 'semitism'},
#  {'amoco', 'trc', 'zrdf01'},
#  {'cardinals', 'favorite', 'unl'},
#  {'chart', 'colorado', 'strip'},
#  {'caps', 'druce', 'hrivnak'},
#  {'boswell', 'rite', 'rites'},
#  {'camelot', 'jemaleddin', 'protestants'},
#  {'alomar', 'pitchers', 'sandberg'},
#  {'fi', 'hut', 'jartsu'},
#  {'jb', 'placebo', 'rr'},
#  {'kirk', 'msoe', 'narlochn'},
#  {'eff', 'gems', 'vcu'},
#  {'cooling', 'nuclear', 'towers'},
#  {'philistines', 'tammy', 'walla'},
#  {'daniels', 'fresco', 'neosoft'},
#  {'_mormons_', 'expulsion', 'holiness'},
#  {'compuserve', 'honda', 'nathan'},
#  {'greenleaf', 'idx', 'tnx'},
#  {'hp', 'tvervaek', 'vervaeke'},
#  {'deposit', 'keys', 'warlord'},
#  {'davidian', 'vay', 'yalanci'},
#  {'cwru', 'freind', 'wisc'},
#  {'jesus', 'josephus', 'lippard'},
#  {'greek', 'iniquity', 'judas'},
#  {'august1', 'augustyn', 'windsor'},
#  {'njd', 'pgh', 'roughing'},
#  {'henneman', 'rochester', 'tigers'},
#  {'air', 'alaska', 'farce'},
#  {'emmons', 'holonet', 'iat'},
#  {'dartmouth', 'hades', 'mouse'},
#  {'season', 'streak', 'unbeaten'},
#  {'dayton', 'hamfest', 'hodge'},
#  {'preasure', 'scicom', 'wag'},
#  {'gak', 'stueven', 'wrs'},
#  {'ibeshir', 'nyx', 'terminal'},
#  {'anwar', 'kuwaitis', 'sarajevo'},
#  {'mouse', 'waikato', 'yale'},
#  {'banks', 'geb', 'tremor'},
#  {'kids', 'spank', 'spanking'},
#  ...]

# %%
best_tfidf[0:5]
# Out:
# [{'car', 'lerxst', 'wam'},
#  {'clock', 'poll', 'si'},
#  {'180', 'powerbook', 'purdue'},
#  {'abraxis', 'harris', 'weitek'},
#  {'bugs', 'errors', 'warning'}]

# %%
links = [{} for _ in range(len(best_tfidf))]

# %%
"""
for i,start in enumerate(best_tfidf):
    for ele in start:
        index = vocab[ele]
        testarr = X_tfidf[:, index]
        js = (-testarr).argsort()[:2] #https://stackoverflow.com/questions/6910641/how-do-i-get-indices-of-n-maximum-values-in-a-numpy-array
        if js[0] == i:
            j = js[1]
        else:
            j = js[0]
        links[i][ele] = j
"""
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-475b917e57be> in <module>
#       3         index = vocab[ele]
#       4         testarr = X_tfidf[:, index]
# ----> 5         js = (-testarr).argsort()[:2] #https://stackoverflow.com/questions/6910641/how-do-i-get-indices-of-n-maximum-values-in-a-numpy-array
#       6         if js[0] == i:
#       7             j = js[1]
#
# ~\miniconda3\lib\site-packages\scipy\sparse\base.py in __getattr__(self, attr)
#     685             return self.getnnz()
#     686         else:
# --> 687             raise AttributeError(attr + " not found")
#     688
#     689     def transpose(self, axes=None, copy=False):
#
# AttributeError: argsort not found

# %%
for i,start in enumerate(best_tfidf):
    for ele in start:
        index = vocab[ele]
        testarr = list(np.transpose(X_tfidf[wordlookup[index], index].toarray())[0])
        reverse = {item:idx for item,idx in zip(list(testarr), wordlookup[index])}
        js = sorted(testarr, reverse=True)
        link = True
        if len(js) <= 1:
            link = False#j = reverse[js[0]]#
        elif reverse[js[0]] == i:
            j = reverse[js[1]]
        else:
            j = reverse[js[0]]
        if link:
            links[i][ele] = j
# Out:
# [0.41534653529092674, 0.18555688223123531, 0.13856139051260066, 0.2219982133321159, 0.07582414290695982, 0.03684690248802452, 0.080454048546352, 0.04059220065593937, 0.037436696060703434, 0.05170342832996582, 0.04969801227949859, 0.27761626091381336, 0.06436596755886116, 0.07132739504331057, 0.14858902017295053, 0.07062089915562728, 0.05217822132082421, 0.07202982972507019, 0.015626056430229643, 0.08491523366758703, 0.07610654084599945, 0.04444435713449442, 0.036925970617987684, 0.04326090335541918, 0.009479887699444235, 0.1280675892492475, 0.07643368279997019, 0.22148716028899637, 0.06486115957454475, 0.05284269780831959, 0.08325773474731911, 0.08254652616707042, 0.12246380747694169, 0.06173774836382614, 0.35642555232469736, 0.06634199645227051, 0.14740297132999128, 0.049570896765602945, 0.13417796458647754, 0.1545488377436988, 0.017529542152058673, 0.056137972224274794, 0.1690942110838241, 0.039319617498703226, 0.041885874484792, 0.07749236056287222, 0.08782995875075592, 0.032290490213751945, 0.21602429679135834, 0.05195399040468082, 0.1656054668576285, 0.45293704541242497, 0.03917012659905087, 0.03379997577900319, 0.1278252161149362, 0.10257390018958706, 0.0451987345554636, 0.13416627799107259, 0.07946756720327965, 0.04233347168884515, 0.092539938632067, 0.09667666982770046, 0.36449143344245627, 0.08915797753933112, 0.01591093240814951, 0.03067454127537051, 0.060403942719402484, 0.1331721381628039, 0.11627794622190267, 0.028563922775098005, 0.0688597237853535, 0.06679013086479443, 0.15779185400324008, 0.030028245142083715, 0.07863188796294608, 0.051750271722853125, 0.05782066515845394, 0.08585664476114302, 0.05829279039347617, 0.1667375801999659, 0.0644640341115746, 0.16268951209625782, 0.07262624734476708, 0.02759239206109757, 0.07695547821271437, 0.032900685576654876, 0.30943893080724977, 0.2110990578687521, 0.0889539541733703, 0.10492736645668113, 0.08403955801909999, 0.04948409544321356, 0.04461237254511245, 0.06164090180180042, 0.09504956910050391, 0.046677161500071916, 0.13639640544938747, 0.081622035511644, 0.019975073546060387, 0.21466851202409723, 0.04296080011756061, 0.09763129115870198, 0.07796686896591445, 0.08193985014987064, 0.021687280525607887, 0.05556192709914691, 0.06429436419618191, 0.07958653723230898, 0.035316799992072045, 0.1757270246779368, 0.054561769477083334, 0.10213019363862749, 0.22709195533615592, 0.1204340869400019, 0.1467228026907188, 0.15059049899871754, 0.02411209307907341, 0.07501404201765813, 0.06562614596048971, 0.028594060353020843, 0.13157361729860984, 0.12096552676519051, 0.09321933589223821, 0.18810633311102343, 0.042164076032620776, 0.36779914618353093, 0.10123986596472968, 0.03564471595766702, 0.037659894920420364, 0.04600116717700332, 0.1147058359515572, 0.06025727900588835, 0.23753302911465707, 0.16871660895673624, 0.12901533082955044, 0.10170315239858035, 0.11433548129628332, 0.06034759473282276, 0.03587123569710872, 0.13113647299778794, 0.09941029165124785, 0.091488200281815, 0.07771160532586714, 0.044237781260576016, 0.0778329379428239, 0.253419109158694, 0.06416104258120328, 0.04443163364219834, 0.09535114031650654, 0.07336540830020201, 0.1030583849834928, 0.3012406518514666, 0.02260628483197947, 0.044802909892168334, 0.10244000497879346, 0.06783954711842627, 0.081372760466561, 0.13601260318558972, 0.04253492507497451, 0.04834607480171424, 0.07528556372732782, 0.07175615242546644, 0.0320138817188209, 0.09767841479783897, 0.04448967296854791, 0.031858198497406676, 0.092983945120436, 0.048896893488893686, 0.07490485870461995, 0.007942521723566316, 0.012475599541094855, 0.12493088985171297, 0.02901980033757184, 0.07529564846503403, 0.01985341560693607, 0.013251899829060566, 0.06713553376639152, 0.1630623003932712, 0.008488539311180307, 0.0865530965530784, 0.04478319881647696, 0.09403059182047452, 0.03873132286449913, 0.059467281644787685, 0.027754016588175515, 0.10963323021281482, 0.060204560769160295, 0.06879765318384795, 0.10039888187234113, 0.11517738001103814, 0.0430045578841 ...
# {0.41534653529092674: 0, 0.18555688223123531: 17, 0.13856139051260066: 29, 0.2219982133321159: 30, 0.07582414290695982: 48, 0.03684690248802452: 56, 0.080454048546352: 64, 0.04059220065593937: 71, 0.037436696060703434: 72, 0.05170342832996582: 77, 0.04969801227949859: 84, 0.27761626091381336: 156, 0.06436596755886116: 181, 0.07132739504331057: 201, 0.14858902017295053: 262, 0.07062089915562728: 274, 0.05217822132082421: 292, 0.07202982972507019: 438, 0.015626056430229643: 491, 0.08491523366758703: 492, 0.07610654084599945: 526, 0.04444435713449442: 534, 0.036925970617987684: 557, 0.04326090335541918: 564, 0.009479887699444235: 565, 0.1280675892492475: 571, 0.07643368279997019: 592, 0.22148716028899637: 596, 0.06486115957454475: 598, 0.05284269780831959: 603, 0.08325773474731911: 621, 0.08254652616707042: 626, 0.12246380747694169: 631, 0.06173774836382614: 655, 0.35642555232469736: 659, 0.06634199645227051: 701, 0.14740297132999128: 730, 0.049570896765602945: 757, 0.13417796458647754: 763, 0.1545488377436988: 771, 0.017529542152058673: 820, 0.056137972224274794: 824, 0.1690942110838241: 830, 0.039319617498703226: 846, 0.041885874484792: 876, 0.07749236056287222: 877, 0.08782995875075592: 910, 0.032290490213751945: 924, 0.21602429679135834: 958, 0.05195399040468082: 980, 0.1656054668576285: 1047, 0.45293704541242497: 1082, 0.03917012659905087: 1086, 0.03379997577900319: 1094, 0.1278252161149362: 1103, 0.10257390018958706: 1111, 0.0451987345554636: 1112, 0.13416627799107259: 1123, 0.07946756720327965: 1126, 0.04233347168884515: 1160, 0.092539938632067: 1183, 0.09667666982770046: 1214, 0.36449143344245627: 1224, 0.08915797753933112: 1287, 0.01591093240814951: 1292, 0.03067454127537051: 1314, 0.060403942719402484: 1324, 0.1331721381628039: 1366, 0.11627794622190267: 1375, 0.028563922775098005: 1383, 0.0688597237853535: 1385, 0.06679013086479443: 1401, 0.15779185400324008: 1432, 0.030028245142083715: 1463, 0.07863188796294608: 1474, 0.051750271722853125: 1494, 0.05782066515845394: 1514, 0.08585664476114302: 1564, 0.05829279039347617: 1595, 0.1667375801999659: 1611, 0.0644640341115746: 1669, 0.16268951209625782: 1687, 0.07262624734476708: 1748, 0.02759239206109757: 1777, 0.07695547821271437: 1789, 0.032900685576654876: 1790, 0.30943893080724977: 1799, 0.2110990578687521: 1820, 0.0889539541733703: 1852, 0.10492736645668113: 1853, 0.08403955801909999: 1938, 0.04948409544321356: 1948, 0.04461237254511245: 1997, 0.06164090180180042: 2008, 0.09504956910050391: 2014, 0.046677161500071916: 2023, 0.13639640544938747: 2086, 0.081622035511644: 2092, 0.019975073546060387: 2108, 0.21466851202409723: 2126, 0.04296080011756061: 2131, 0.09763129115870198: 2134, 0.07796686896591445: 2162, 0.08193985014987064: 2183, 0.021687280525607887: 2200, 0.05556192709914691: 2228, 0.06429436419618191: 2231, 0.07958653723230898: 2255, 0.035316799992072045: 2272, 0.1757270246779368: 2273, 0.054561769477083334: 2275, 0.10213019363862749: 2285, 0.22709195533615592: 2312, 0.1204340869400019: 2333, 0.1467228026907188: 2353, 0.15059049899871754: 2363, 0.02411209307907341: 2372, 0.07501404201765813: 2379, 0.06562614596048971: 2383, 0.028594060353020843: 2389, 0.13157361729860984: 2407, 0.12096552676519051: 2414, 0.09321933589223821: 2496, 0.18810633311102343: 2519, 0.042164076032620776: 2522, 0.36779914618353093: 2554, 0.10123986596472968: 2570, 0.03564471595766702: 2588, 0.037659894920420364: 2612, 0.04600116717700332: 2615, 0.1147058359515572: 2637, 0.06025727900588835: 2643, 0.23753302911465707: 2648, 0.16871660895673624: 2656, 0.12901533082955044: 2660, 0.10170315239858035: 2664, 0.11433548129628332: 2712, 0.06034759473282276: 2715, 0.03587123569710872: 2735, 0.13113647299778794: 2749, 0.09941029165124785: 2781, 0.091488200281815: 2795, 0.07771160532586714: 2796, 0.044237781260576016: 2802, 0.0778329379428239: 2834, 0.253419109158694: 2845, 0.06416104258120328: 2886, 0.04443163364219834: 2892, 0.09535114031650654: 2942, 0.07336540830020201: 2951, 0.1030583849834928 ...
# 573
# [0.5229043426930199, 0.47025599322296496, 0.45293704541242497, 0.41534653529092674, 0.37325079201980943, 0.36779914618353093, 0.36449143344245627, 0.35642555232469736, 0.3441264150857614, 0.3328075346606165, 0.3248612917783662, 0.3139740380586551, 0.30943893080724977, 0.3083715198153782, 0.3055266657604773, 0.3012406518514666, 0.29003864834847215, 0.2796332567556969, 0.278916456837317, 0.27761626091381336, 0.26352263375547696, 0.25357270341035243, 0.253419109158694, 0.2530248495138723, 0.25025181447324824, 0.245891594951, 0.24056895183427582, 0.23753302911465707, 0.23720547491709482, 0.23407422154871546, 0.23312562386941693, 0.23159934275353625, 0.23121075676959854, 0.2292243577905261, 0.22813178347551016, 0.22709195533615592, 0.2270488611848088, 0.22442110417454636, 0.2219982133321159, 0.22148716028899637, 0.21605953347896803, 0.21602429679135834, 0.21466851202409723, 0.2110990578687521, 0.20807682961463306, 0.2063320224404406, 0.20358141416347997, 0.20095833374848907, 0.20025519405615325, 0.19942340360589134, 0.19905735221886728, 0.19716937271096535, 0.19551130354228943, 0.19454707000268232, 0.19013170337207858, 0.18873468596493148, 0.18810633311102343, 0.18555688223123531, 0.18551806300618426, 0.18512135981237549, 0.1840097954495113, 0.18176075094435046, 0.17873482388682482, 0.1773911831945856, 0.17647924622197247, 0.1757270246779368, 0.17226741089632522, 0.17202617478019241, 0.1720188926781189, 0.1690942110838241, 0.16871660895673624, 0.1667375801999659, 0.1656054668576285, 0.1630623003932712, 0.16297659535954945, 0.162910986991046, 0.16268951209625782, 0.16084215517396552, 0.15779185400324008, 0.1570642184314076, 0.156236796351947, 0.15597889923327493, 0.15499292467671627, 0.1545488377436988, 0.1525837706588503, 0.15134891825407557, 0.15059049899871754, 0.15024661965220057, 0.14959214618434685, 0.14931177242837626, 0.14858902017295053, 0.14774065905492542, 0.1476502992805815, 0.1476289117414725, 0.14740297132999128, 0.1467228026907188, 0.14658293393728786, 0.14624262517547434, 0.1454664766194944, 0.1453666703722834, 0.14532328740140438, 0.14477490457503922, 0.1432906287556024, 0.143225130154108, 0.14188777056131688, 0.14144737575614863, 0.14044253537695842, 0.13902842404171983, 0.13856139051260066, 0.1382598025936982, 0.13639640544938747, 0.13601260318558972, 0.13417796458647754, 0.13416627799107259, 0.1331721381628039, 0.13297376240410827, 0.13250048322348823, 0.13223344675636547, 0.13157361729860984, 0.13113647299778794, 0.12901533082955044, 0.12894477643053956, 0.128747767285127, 0.12854404706225458, 0.1280675892492475, 0.1278252161149362, 0.12633561258125375, 0.1261135186126326, 0.12493088985171297, 0.1244335656783412, 0.12414295142901384, 0.1241147756699745, 0.12344259135065659, 0.1234109162189657, 0.12306957324615393, 0.12252059047917327, 0.12246380747694169, 0.12180168890603943, 0.12096552676519051, 0.12052451220975358, 0.12048508528127003, 0.1204340869400019, 0.12005462285013423, 0.12004297074071148, 0.11775284491870087, 0.11659813944068058, 0.11627794622190267, 0.11523364862935413, 0.11517738001103814, 0.1149780120480478, 0.1147058359515572, 0.11433548129628332, 0.11396556682675009, 0.11377146594564852, 0.11360400698423465, 0.11294060590617087, 0.11260138217788722, 0.11240011606213979, 0.11214058984993731, 0.11025747373162711, 0.10963323021281482, 0.10926174795078886, 0.10841704151219334, 0.10702287192384256, 0.10647917040923058, 0.10615513902978077, 0.1056003245807809, 0.10555197658455327, 0.10538520619594696, 0.1049670685358141, 0.10492736645668113, 0.10480621357285529, 0.1030583849834928, 0.10294911844194511, 0.10289976379120937, 0.10257390018958706, 0.10244000497879346, 0.10213019363862749, 0.10211754584735162, 0.10175173069200726, 0.10170315239858035, 0.10156768798777532, 0.10123986596472968, 0.10115139680539369, 0.10039888187234113, 0.09994807323670073, 0.09941029165124785, 0.09837128168950582, 0.09767841479783897, 0.09763129115870198, 0.09740283537210966, 0.09688265381938656, 0.09667666982770046, 0.0966472 ...
# [0.41534653529092674, 0.18555688223123531, 0.13856139051260066, 0.2219982133321159, 0.07582414290695982, 0.03684690248802452, 0.080454048546352, 0.04059220065593937, 0.037436696060703434, 0.05170342832996582, 0.04969801227949859, 0.27761626091381336, 0.06436596755886116, 0.07132739504331057, 0.14858902017295053, 0.07062089915562728, 0.05217822132082421, 0.07202982972507019, 0.015626056430229643, 0.08491523366758703, 0.07610654084599945, 0.04444435713449442, 0.036925970617987684, 0.04326090335541918, 0.009479887699444235, 0.1280675892492475, 0.07643368279997019, 0.22148716028899637, 0.06486115957454475, 0.05284269780831959, 0.08325773474731911, 0.08254652616707042, 0.12246380747694169, 0.06173774836382614, 0.35642555232469736, 0.06634199645227051, 0.14740297132999128, 0.049570896765602945, 0.13417796458647754, 0.1545488377436988, 0.017529542152058673, 0.056137972224274794, 0.1690942110838241, 0.039319617498703226, 0.041885874484792, 0.07749236056287222, 0.08782995875075592, 0.032290490213751945, 0.21602429679135834, 0.05195399040468082, 0.1656054668576285, 0.45293704541242497, 0.03917012659905087, 0.03379997577900319, 0.1278252161149362, 0.10257390018958706, 0.0451987345554636, 0.13416627799107259, 0.07946756720327965, 0.04233347168884515, 0.092539938632067, 0.09667666982770046, 0.36449143344245627, 0.08915797753933112, 0.01591093240814951, 0.03067454127537051, 0.060403942719402484, 0.1331721381628039, 0.11627794622190267, 0.028563922775098005, 0.0688597237853535, 0.06679013086479443, 0.15779185400324008, 0.030028245142083715, 0.07863188796294608, 0.051750271722853125, 0.05782066515845394, 0.08585664476114302, 0.05829279039347617, 0.1667375801999659, 0.0644640341115746, 0.16268951209625782, 0.07262624734476708, 0.02759239206109757, 0.07695547821271437, 0.032900685576654876, 0.30943893080724977, 0.2110990578687521, 0.0889539541733703, 0.10492736645668113, 0.08403955801909999, 0.04948409544321356, 0.04461237254511245, 0.06164090180180042, 0.09504956910050391, 0.046677161500071916, 0.13639640544938747, 0.081622035511644, 0.019975073546060387, 0.21466851202409723, 0.04296080011756061, 0.09763129115870198, 0.07796686896591445, 0.08193985014987064, 0.021687280525607887, 0.05556192709914691, 0.06429436419618191, 0.07958653723230898, 0.035316799992072045, 0.1757270246779368, 0.054561769477083334, 0.10213019363862749, 0.22709195533615592, 0.1204340869400019, 0.1467228026907188, 0.15059049899871754, 0.02411209307907341, 0.07501404201765813, 0.06562614596048971, 0.028594060353020843, 0.13157361729860984, 0.12096552676519051, 0.09321933589223821, 0.18810633311102343, 0.042164076032620776, 0.36779914618353093, 0.10123986596472968, 0.03564471595766702, 0.037659894920420364, 0.04600116717700332, 0.1147058359515572, 0.06025727900588835, 0.23753302911465707, 0.16871660895673624, 0.12901533082955044, 0.10170315239858035, 0.11433548129628332, 0.06034759473282276, 0.03587123569710872, 0.13113647299778794, 0.09941029165124785, 0.091488200281815, 0.07771160532586714, 0.044237781260576016, 0.0778329379428239, 0.253419109158694, 0.06416104258120328, 0.04443163364219834, 0.09535114031650654, 0.07336540830020201, 0.1030583849834928, 0.3012406518514666, 0.02260628483197947, 0.044802909892168334, 0.10244000497879346, 0.06783954711842627, 0.081372760466561, 0.13601260318558972, 0.04253492507497451, 0.04834607480171424, 0.07528556372732782, 0.07175615242546644, 0.0320138817188209, 0.09767841479783897, 0.04448967296854791, 0.031858198497406676, 0.092983945120436, 0.048896893488893686, 0.07490485870461995, 0.007942521723566316, 0.012475599541094855, 0.12493088985171297, 0.02901980033757184, 0.07529564846503403, 0.01985341560693607, 0.013251899829060566, 0.06713553376639152, 0.1630623003932712, 0.008488539311180307, 0.0865530965530784, 0.04478319881647696, 0.09403059182047452, 0.03873132286449913, 0.059467281644787685, 0.027754016588175515, 0.10963323021281482, 0.060204560769160295, 0.06879765318384795, 0.10039888187234113, 0.11517738001103814, 0.0430045578841 ...
# 573
# [0.282869751755441, 0.10374562709979798, 0.14712230394244993, 0.009155178132919073, 0.07760022945241914, 0.146475976234815, 0.4452330325798546, 0.3037492870498392, 0.3118870254171318, 0.11116937247254903, 0.07836719953494742, 0.223255158045446, 0.2840050702543252, 0.28067348277432297, 0.18414600267041395, 0.12727688595337397, 0.4490200953434677, 0.08117479034032987, 0.193944741916641, 0.28105702286419, 0.10566141028217022, 0.24268835116434667, 0.16586866707720982, 0.07164736423380523, 0.05357347331933384, 0.15848801764360157, 0.06320362716244401, 0.12702191078178357, 0.1291021638446568, 0.15608555430822765, 0.34930130221849703, 0.3527433436900425, 0.5034072151615078, 0.12109731613080986]
# {0.282869751755441: 0, 0.10374562709979798: 68, 0.14712230394244993: 958, 0.009155178132919073: 1128, 0.07760022945241914: 1322, 0.146475976234815: 2475, 0.4452330325798546: 3277, 0.3037492870498392: 3678, 0.3118870254171318: 4130, 0.11116937247254903: 4413, 0.07836719953494742: 4566, 0.223255158045446: 4660, 0.2840050702543252: 5253, 0.28067348277432297: 5496, 0.18414600267041395: 5655, 0.12727688595337397: 6214, 0.4490200953434677: 6932, 0.08117479034032987: 6934, 0.193944741916641: 7212, 0.28105702286419: 7380, 0.10566141028217022: 7541, 0.24268835116434667: 7774, 0.16586866707720982: 7872, 0.07164736423380523: 7971, 0.05357347331933384: 8106, 0.15848801764360157: 9134, 0.06320362716244401: 9918, 0.12702191078178357: 10261, 0.1291021638446568: 10335, 0.15608555430822765: 10374, 0.34930130221849703: 10464, 0.3527433436900425: 10533, 0.5034072151615078: 10576, 0.12109731613080986: 10614}
# 34
# [0.5034072151615078, 0.4490200953434677, 0.4452330325798546, 0.3527433436900425, 0.34930130221849703, 0.3118870254171318, 0.3037492870498392, 0.2840050702543252, 0.282869751755441, 0.28105702286419, 0.28067348277432297, 0.24268835116434667, 0.223255158045446, 0.193944741916641, 0.18414600267041395, 0.16586866707720982, 0.15848801764360157, 0.15608555430822765, 0.14712230394244993, 0.146475976234815, 0.1291021638446568, 0.12727688595337397, 0.12702191078178357, 0.12109731613080986, 0.11116937247254903, 0.10566141028217022, 0.10374562709979798, 0.08117479034032987, 0.07836719953494742, 0.07760022945241914, 0.07164736423380523, 0.06320362716244401, 0.05357347331933384, 0.009155178132919073]
# [0.282869751755441, 0.10374562709979798, 0.14712230394244993, 0.009155178132919073, 0.07760022945241914, 0.146475976234815, 0.4452330325798546, 0.3037492870498392, 0.3118870254171318, 0.11116937247254903, 0.07836719953494742, 0.223255158045446, 0.2840050702543252, 0.28067348277432297, 0.18414600267041395, 0.12727688595337397, 0.4490200953434677, 0.08117479034032987, 0.193944741916641, 0.28105702286419, 0.10566141028217022, 0.24268835116434667, 0.16586866707720982, 0.07164736423380523, 0.05357347331933384, 0.15848801764360157, 0.06320362716244401, 0.12702191078178357, 0.1291021638446568, 0.15608555430822765, 0.34930130221849703, 0.3527433436900425, 0.5034072151615078, 0.12109731613080986]
# 34
# [0.3853898515642234, 0.20044364067313794]
# {0.3853898515642234: 0, 0.20044364067313794: 958}
# 2
# [0.3853898515642234, 0.20044364067313794]
# [0.3853898515642234, 0.20044364067313794]
# 2

# %%
links[0:5]
# Out:
# [{'wam': 10576, 'car': 8266, 'lerxst': 958},
#  {'si': 7204, 'poll': 2792, 'clock': 4693},
#  {'purdue': 2368, '180': 11141, 'powerbook': 3620},
#  {'harris': 2924, 'abraxis': 8164, 'weitek': 5221},
#  {'errors': 11191, 'bugs': 1591, 'warning': 4098}]

# %%
links[0:5]
# Out:
# [{'car': 8266, 'wam': 10576, 'lerxst': 958},
#  {'si': 7204, 'clock': 4693, 'poll': 2792},
#  {'purdue': 2368, '180': 11141, 'powerbook': 3620},
#  {'harris': 2924, 'abraxis': 8164, 'weitek': 5221},
#  {'errors': 11191, 'bugs': 1591, 'warning': 4098}]

# %%
re.findall('lerxst', X[0], re.IGNORECASE)
# Out:
# ['lerxst', 'Lerxst']

# %%
X[958].find('rseymour')
# Out:
# 6

# %%
X[659]
# Out:
# 'From: boyle@cactus.org (Craig Boyle)\nSubject: Re: New break pads & exhausts after 96K km (60K mi) on \'90 Maxima?\nOrganization: Capital Area Central Texas UNIX Society, Austin, Tx\nLines: 78\n\nIn article <1993Apr16.000601.14223@jarvis.csri.toronto.edu> rkim@eecg.toronto.edu (Ryan Kim) writes:\n>\n>Hi, maybe someone can help me here...\n>I am looking to buy this 1990 Nissan Maxima GXE for CDN$14000 right now.\n\nSo its an automatic? Don\'t know if US spec=CDN spec. for Maximas.\n\n>The car has 96000 km (or about 60000 miles) on it.\n>A typical mileage for 1990 cars seem to be about 70000 km (or about 43K mi).\n>The seller just informed me that when he brought the car in for certification\n>he was told that the front break pads and the exhausts had to be replaced\n>to meet the legal standards.  (He said he will replace the components before\n>selling the car to me.)\n>\n>Being copmletely ignorant to the technical stuff on cars, I don\'t know\n>what this could mean...\n>Is 96K km about the time typical for replacing the above mentioned items?\n>Or is this an indication that the car was abused?\n\nIf it is the first set of brake pads on front, then this is fine. My car\neats a set every 15k miles or so. The fact that he is replacing the\nmuffler too is also ok.\n\n>Would other things break down or have to be replaced soon?\n\nThe mileage is fairly low - but typical fwd stuff is CV joints. Check\nthe maintenance records with the manufacturers requirements for valve\nadjustments, timing belt changes and so on.\n\nThe 60k mile service is often expensive, so make sure he has done everything.\n\n\n>The seller told me that he used the car on the highway a lot, but,\n>I don\'t know how to verify this...  I\'ve seen the paint chipped away\n>in tiny dots in the front edge of the hood, though.\n>\nWell, this is one of the commonly cited methods for identifying a\ncar with highway miles. \nMight check the gas pedal wear too. Ask him how many sets of tires he\nhas been through. A highway car might have squeezed by on 2 sets,\na hard driven car 6-10 sets.\n\n\n>Although the Maxima is an excellent car and the car is very clean and\n>well kept, it\'s currently out of warranty\n>(a similarly priced \'90 Accord with 70K km will have 2 years or 30K km\n>worth of warranty left) and I don\'t want to worry about paying for\n>any repair bills...\n\nWell, the Maxima should be pretty reliable - but if its out of warranty\nyou should get it checked out by someone knowledgeable first. Stuff\nfor Japanese cars can be expensive.\n\n>But, I also need a car for 5 people...  \n>\n>When will the new Maxima come out, by the way?\n\n1995 model year, I believe. \n>\n>I would very much appreciate your input in this.\n>Please reply by e-mail (preferred) or post in this newsgroup.\n\nCraig\n>Thanks!\n>\n>Ryan\n>\n>\n>\n>========\n>Ryan Kim\n>University of Toronto, EECG, Computer Graphics    rkim@eecg.toronto.edu\n>"Do not weave between traffic cones at road works."\n>                                    - from the new British Highway Code\n>                                           (Toronto Star April 3, 1993)\n>\n\n\n'
